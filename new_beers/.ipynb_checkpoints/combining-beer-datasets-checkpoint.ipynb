# %%
import pandas as pd #for building dataframes from CSV files
import glob, os #for reading file names
import seaborn as sns #for fancy charts
import numpy as np #for np.nan
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Reading CSV files in the DIR
file_names = []
file_names = glob.glob('*.csv')

# %%
#Var to check if it is the first load
load_counter = 0

#Loading files into single dataframe
for file in file_names :
    df = pd.read_csv(file)
    if load_counter == 0 :
        final_df = df.copy()
    else :
        final_df = final_df.append(df, ignore_index=True)
    load_counter += 1

# %%
#Check info
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29175 entries, 0 to 29174
# Data columns (total 53 columns):
# auth_rating                       29175 non-null int64
# beer_abv                          29175 non-null float64
# beer_description                  17432 non-null object
# beer_ibu                          29175 non-null int64
# beer_label                        29175 non-null object
# beer_label_hd                     9066 non-null object
# beer_name                         29175 non-null object
# beer_slug                         29005 non-null object
# beer_style                        29174 non-null object
# bid                               29175 non-null int64
# brewery.brewery_id                29175 non-null int64
# brewery.brewery_label             29175 non-null object
# brewery.brewery_name              29175 non-null object
# brewery.brewery_slug              29164 non-null object
# brewery.brewery_type              29175 non-null object
# ...

# %%
#column count
len(final_df.columns)
# Out:
# 53

# %%
#Check col names
final_df.columns
# Out:
# Index(['auth_rating', 'beer_abv', 'beer_description', 'beer_ibu', 'beer_label',
#        'beer_label_hd', 'beer_name', 'beer_slug', 'beer_style', 'bid',
#        'brewery.brewery_id', 'brewery.brewery_label', 'brewery.brewery_name',
#        'brewery.brewery_slug', 'brewery.brewery_type',
#        'brewery.contact.facebook', 'brewery.contact.twitter',
#        'brewery.contact.url', 'brewery.country_name',
#        'brewery.location.brewery_city', 'brewery.location.brewery_state',
#        'brewery.location.lat', 'brewery.location.lng',
#        'collaborations_with.count', 'collaborations_with.items', 'created_at',
#        'is_homebrew', 'is_in_production', 'merge_details.master_bid',
#        'merge_details.merge_date', 'merge_details.requested_bid',
#        'rating_count', 'rating_score', 'rating_score_below',
#        'stats.monthly_count', 'stats.total_count', 'stats.total_user_count',
#        'stats.user_count', 'variant_parent.beer.beer_abv',
# ...

# %%
#remove difficult to handle duplicates, based on the "merge_details" fields
final_df['merge_details.merge_date'].fillna('none', inplace=True)

# %%
#filter so that only the original entries exist
final_df = final_df[final_df['merge_details.merge_date'] == 'none']

# %%
#List of ALL columns to drop for various reasons. Descriptions, hyperlinks, social media, etc.
drop_cols = ['auth_rating', 'beer_description', 'beer_label', 'beer_label_hd', 'beer_slug', 'brewery.brewery_slug',
            'brewery.contact.facebook', 'brewery.contact.twitter', 'brewery.contact.url', 'rating_score_below', 
            'variant_parent.beer.beer_abv', 'variant_parent.beer.beer_name', 'variant_parent.beer.beer_slug',
            'variant_parent.beer.bid', 'variant_parent.beer.type_id', 'brewery.brewery_label', 
            'vintage_parent.beer.beer_abv', 'vintage_parent.beer.beer_name', 'stats.user_count', 
            'vintage_parent.beer.beer_slug', 'vintage_parent.beer.bid', 
            'vintage_parent.beer.type_id', 'merge_details.master_bid',
            'merge_details.merge_date', 'merge_details.requested_bid', 'vintages.count', 'vintages.items', 
            'collaborations_with.count', 'collaborations_with.items', 'vintage_parent']

# %%
len(drop_cols)
# Out:
# 30

# %%
#Drop unnecessary columns
final_df.drop(drop_cols, axis=1, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20069 entries, 0 to 29174
# Data columns (total 23 columns):
# beer_abv                          20069 non-null float64
# beer_ibu                          20069 non-null int64
# beer_name                         20069 non-null object
# beer_style                        20069 non-null object
# bid                               20069 non-null int64
# brewery.brewery_id                20069 non-null int64
# brewery.brewery_name              20069 non-null object
# brewery.brewery_type              20069 non-null object
# brewery.country_name              20069 non-null object
# brewery.location.brewery_city     18019 non-null object
# brewery.location.brewery_state    16490 non-null object
# brewery.location.lat              20069 non-null float64
# brewery.location.lng              20069 non-null float64
# created_at                        20069 non-null object
# is_homebrew                       20069 non-null int64
# ...

# %%
#Check for any duplicate beers
final_df.drop_duplicates(inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19887 entries, 0 to 29174
# Data columns (total 23 columns):
# beer_abv                          19887 non-null float64
# beer_ibu                          19887 non-null int64
# beer_name                         19887 non-null object
# beer_style                        19887 non-null object
# bid                               19887 non-null int64
# brewery.brewery_id                19887 non-null int64
# brewery.brewery_name              19887 non-null object
# brewery.brewery_type              19887 non-null object
# brewery.country_name              19887 non-null object
# brewery.location.brewery_city     17856 non-null object
# brewery.location.brewery_state    16336 non-null object
# brewery.location.lat              19887 non-null float64
# brewery.location.lng              19887 non-null float64
# created_at                        19887 non-null object
# is_homebrew                       19887 non-null int64
# ...

# %%
#Search for any remaining duplicates, this is a pain, but necessary activity
final_df.groupby('bid').size().sort_values(ascending=False).head(25)
# Out:
# bid
# 11093    2
# 9310     2
# 9607     2
# 3762     2
# 25053    2
# 21882    2
# 8914     2
# 13667    2
# 4158     2
# 1384     2
# 26241    2
# 5942     2
# 30203    2
# 11489    2
# 16631    2
# 6834     2
# 13073    2
# 26043    2
# 12578    2
# 25944    2
# 9706     1
# 9705     1
# 9704     1
# 9702     1
# 9697     1
# dtype: int64

# %%
#Search one-by-one for the remaining duplicates and remove below
final_df[final_df['bid'] == 26043]
# Out:
#        beer_abv  beer_ibu       beer_name                      beer_style  \
# 17125       5.4        40  Rip Tide Amber  Red Ale - American Amber / Red
# 17126       5.4        40  Rip Tide Amber  Red Ale - American Amber / Red
#
#          bid  brewery.brewery_id   brewery.brewery_name brewery.brewery_type  \
# 17125  26043                7115  Pensacola Bay Brewery        Micro Brewery
# 17126  26043                7115  Pensacola Bay Brewery        Micro Brewery
#
#       brewery.country_name brewery.location.brewery_city    ...      \
# 17125        United States                     Pensacola    ...
# 17126        United States                     Pensacola    ...
#
#                             created_at  is_homebrew  is_in_production  \
# 17125  Sun, 23 Jan 2011 02:50:35 +0000            0                 1
# 17126  Sun, 23 Jan 2011 02:50:35 +0000            0                 1
#
#       rating_count  rating_score  stats.monthly_count  stats.total_count  \
# ...

# %%
#Drop the remaining records that are problematic duplicates (drop by index #)
final_df.drop([1355, 28327, 28609, 22797, 16041, 12779, 27960, 4080, 23280, 4178, 17319, 24821, 21623, 1747, 7191,
               25682, 3493, 17125, 2903, 17025], inplace=True)

# %%
#Search for any remaining duplicates, this is a pain, but necessary activity
final_df.groupby('bid').size().sort_values(ascending=False).head(5)
# Out:
# bid
# 30699    1
# 9705     1
# 9696     1
# 9697     1
# 9698     1
# dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19867 entries, 0 to 29174
# Data columns (total 23 columns):
# beer_abv                          19867 non-null float64
# beer_ibu                          19867 non-null int64
# beer_name                         19867 non-null object
# beer_style                        19867 non-null object
# bid                               19867 non-null int64
# brewery.brewery_id                19867 non-null int64
# brewery.brewery_name              19867 non-null object
# brewery.brewery_type              19867 non-null object
# brewery.country_name              19867 non-null object
# brewery.location.brewery_city     17836 non-null object
# brewery.location.brewery_state    16320 non-null object
# brewery.location.lat              19867 non-null float64
# brewery.location.lng              19867 non-null float64
# created_at                        19867 non-null object
# is_homebrew                       19867 non-null int64
# ...

# %%
final_df.columns
# Out:
# Index(['beer_abv', 'beer_ibu', 'beer_name', 'beer_style', 'bid',
#        'brewery.brewery_id', 'brewery.brewery_name', 'brewery.brewery_type',
#        'brewery.country_name', 'brewery.location.brewery_city',
#        'brewery.location.brewery_state', 'brewery.location.lat',
#        'brewery.location.lng', 'created_at', 'is_homebrew', 'is_in_production',
#        'rating_count', 'rating_score', 'stats.monthly_count',
#        'stats.total_count', 'stats.total_user_count', 'weighted_rating_score',
#        'wish_list'],
#       dtype='object')

# %%
#fill remaining null values with "Unknown"
final_df.fillna('NO_INFORMATION', inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19867 entries, 0 to 29174
# Data columns (total 23 columns):
# beer_abv                          19867 non-null float64
# beer_ibu                          19867 non-null int64
# beer_name                         19867 non-null object
# beer_style                        19867 non-null object
# bid                               19867 non-null int64
# brewery.brewery_id                19867 non-null int64
# brewery.brewery_name              19867 non-null object
# brewery.brewery_type              19867 non-null object
# brewery.country_name              19867 non-null object
# brewery.location.brewery_city     19867 non-null object
# brewery.location.brewery_state    19867 non-null object
# brewery.location.lat              19867 non-null float64
# brewery.location.lng              19867 non-null float64
# created_at                        19867 non-null object
# is_homebrew                       19867 non-null int64
# ...

# %%
#Check the weighted rating score distribution 
sns.distplot(final_df['weighted_rating_score'], axlabel='Initial Load: Beer Ratings')

# %%
#verify count of 0.0 values for ratings
final_df[final_df['weighted_rating_score'] == 0.0].count()
# Out:
# beer_abv                          29
# beer_ibu                          29
# beer_name                         29
# beer_style                        29
# bid                               29
# brewery.brewery_id                29
# brewery.brewery_name              29
# brewery.brewery_type              29
# brewery.country_name              29
# brewery.location.brewery_city     29
# brewery.location.brewery_state    29
# brewery.location.lat              29
# brewery.location.lng              29
# created_at                        29
# is_homebrew                       29
# is_in_production                  29
# rating_count                      29
# rating_score                      29
# stats.monthly_count               29
# stats.total_count                 29
# stats.total_user_count            29
# weighted_rating_score             29
# wish_list                         29
# dtype: int64

# %%
final_df['weighted_rating_score'].describe()
# Out:
# count    19867.000000
# mean         3.524786
# std          0.356703
# min          0.000000
# 25%          3.491960
# 50%          3.589430
# 75%          3.649190
# max          4.749380
# Name: weighted_rating_score, dtype: float64

# %%
filtered_df = final_df[final_df['weighted_rating_score'] > 0.0]
filtered_df['weighted_rating_score'].describe()
# Out:
# count    19838.000000
# mean         3.529939
# std          0.330505
# min          1.081710
# 25%          3.492635
# 50%          3.589645
# 75%          3.649280
# max          4.749380
# Name: weighted_rating_score, dtype: float64

# %%
sns.distplot(filtered_df['weighted_rating_score'], axlabel='Weighted Rated Beer Ratings')

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19838 entries, 0 to 29174
# Data columns (total 23 columns):
# beer_abv                          19838 non-null float64
# beer_ibu                          19838 non-null int64
# beer_name                         19838 non-null object
# beer_style                        19838 non-null object
# bid                               19838 non-null int64
# brewery.brewery_id                19838 non-null int64
# brewery.brewery_name              19838 non-null object
# brewery.brewery_type              19838 non-null object
# brewery.country_name              19838 non-null object
# brewery.location.brewery_city     19838 non-null object
# brewery.location.brewery_state    19838 non-null object
# brewery.location.lat              19838 non-null float64
# brewery.location.lng              19838 non-null float64
# created_at                        19838 non-null object
# is_homebrew                       19838 non-null int64
# ...

# %%
#ad-hoc analysis on other quantitative factors
sns.boxplot(x='beer_abv', orient='v', data=filtered_df)

# %%
#ad-hoc analysis on other quantitative factors
sns.boxplot(x='beer_ibu', orient='v', data=filtered_df)

# %%
sns.pairplot(filtered_df)

# %%
#Save dataframe to CSV file for analysis
filtered_df.to_csv('final-avg-user-beer-data.csv', index=False)
