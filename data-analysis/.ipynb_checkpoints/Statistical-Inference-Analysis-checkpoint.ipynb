# %% [markdown]
# # Capstone Project #1: Stastistical Inference & Analysis

# %% [markdown]
# ## Primary Questions:
# 1. Do any of the characteristics of the beer (e.g. alcohol by volume or abv) tend to influence my ratings?
# 2. Is there a significant difference between my individual set of beer ratings when compared to the average user? If yes/no, what does this mean for future prediction methodologies?

# %%
import pandas as pd #for building dataframes from CSV files
import seaborn as sns #for fancy charts
import numpy as np #for np.nan
from scipy import stats #for statistical analysis
from scipy.stats import norm #for statistical analysis
from datetime import datetime #for time-series plots
import statsmodels #for integration with pandas and analysis
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
#Initialize dataframes given API data
#This dataset is the set of beers that i have personally tasted and rated
my_beer_df = pd.read_csv('../data/my-final-beer-data.csv')

# %%
#always check info()
my_beer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 35 columns):
# beer.auth_rating                  181 non-null float64
# beer.beer_abv                     181 non-null float64
# beer.beer_description             181 non-null object
# beer.beer_ibu                     181 non-null int64
# beer.beer_label                   181 non-null object
# beer.beer_name                    181 non-null object
# beer.beer_slug                    181 non-null object
# beer.beer_style                   181 non-null object
# beer.bid                          181 non-null int64
# beer.created_at                   181 non-null object
# beer.rating_count                 181 non-null int64
# beer.rating_score                 181 non-null float64
# beer.wish_list                    181 non-null bool
# brewery.brewery_active            181 non-null int64
# brewery.brewery_id                181 non-null int64
# brewery.brewery_label             181 non-null object
# brewery.brewery_name              181 non-null object
# brewery.brewery_slug              181 non-null object
# brewery.contact.facebook          181 non-null object
# brewery.contact.instagram         181 non-null object
# brewery.contact.twitter           181 non-null object
# brewery.contact.url               181 non-null object
# brewery.country_name              181 non-null object
# brewery.location.brewery_city     181 non-null object
# brewery.location.brewery_state    181 non-null object
# brewery.location.lat              181 non-null float64
# brewery.location.lng              181 non-null float64
# count                             181 non-null int64
# first_checkin_id                  181 non-null int64
# first_created_at                  181 non-null object
# first_had                         181 non-null object
# rating_score                      181 non-null float64
# recent_checkin_id                 181 non-null int64
# recent_created_at                 181 non-null object
# recent_created_at_timezone        181 non-null int64
# dtypes: bool(1), float64(6), int64(9), object(19)
# memory usage: 48.3+ KB

# %%
#Let's check the statistics around the quantitative factors
my_beer_df.describe()
# Out:
#        beer.auth_rating  beer.beer_abv  beer.beer_ibu      beer.bid  \
# count        181.000000     181.000000     181.000000  1.810000e+02
# mean           3.392265       5.870442      27.127072  4.060896e+05
# std            0.642906       1.900491      77.978276  5.526310e+05
# min            1.500000       0.000000       0.000000  1.540000e+02
# 25%            3.000000       5.000000       0.000000  1.197400e+04
# 50%            3.500000       5.400000       0.000000  6.970200e+04
# 75%            3.750000       6.370000      40.000000  7.277380e+05
# max            5.000000      16.900000    1000.000000  1.932539e+06
#
#        beer.rating_count  beer.rating_score  brewery.brewery_active  \
# count         181.000000         181.000000                   181.0
# mean        23517.895028           3.438840                     1.0
# std         45528.404033           0.398313                     0.0
# min            18.000000           2.319000                     1.0
# 25%           986.000000           3.168000                     1.0
# 50%          4414.000000           3.537000                     1.0
# 75%         21438.000000           3.729000                     1.0
# max        340554.000000           4.560000                     1.0
#
#        brewery.brewery_id  brewery.location.lat  brewery.location.lng  \
# count          181.000000            181.000000            181.000000
# mean         35393.983425             22.990224            -12.951038
# std          72053.724608             28.034327             88.612863
# min             17.000000            -53.155200           -156.437000
# 25%           1204.000000              4.717360            -87.900200
# 50%           4573.000000             35.643200              0.000000
# 75%          19884.000000             42.314400             19.932100
# max         299073.000000             58.356800            174.780000
#
#             count  first_checkin_id  rating_score  recent_checkin_id  \
# count  181.000000      1.810000e+02    181.000000       1.810000e+02
# mean     1.016575      3.797118e+08      3.392265       3.808877e+08
# std      0.128025      4.582607e+07      0.642906       4.570316e+07
# min      1.000000      2.943933e+08      1.500000       2.943933e+08
# 25%      1.000000      3.364364e+08      3.000000       3.378019e+08
# 50%      1.000000      3.761521e+08      3.500000       3.764025e+08
# 75%      1.000000      4.255308e+08      3.750000       4.263267e+08
# max      2.000000      4.493459e+08      5.000000       4.493459e+08
#
#        recent_created_at_timezone
# count                  181.000000
# mean                     0.447514
# std                      6.160245
# min                     -8.000000
# 25%                     -5.000000
# 50%                      2.000000
# 75%                      7.000000
# max                     12.000000

# %% [markdown]
# # 1. Do any of the characteristics of the beer (e.g. alcohol by volume or abv) tend to influence my ratings?

# %%
#let's visualize my ratings vs beer alcohol by volume content
sns.jointplot(x="beer.beer_abv", y="beer.auth_rating", data=my_beer_df, kind='reg', color='teal', size=8);

# %% [markdown]
# ## As we can see in the plot above, with r=0.4 there is a slight positive correlation, but not too signficant. There seem to be other factors at play, other than ABV that dictate my ratings.

# %%
#let's visualize my ratings vs beer bitterness content (ibu)
sns.jointplot(x="beer.beer_ibu", y="beer.auth_rating", data=my_beer_df, kind='reg', color='orange', size=8);

# %% [markdown]
# ## It appears that 'beer_ibu' has some data integrity issues as many of the beers have a beer_ibu = 0.

# %%
#let's visualize my ratings vs brewery (manufacturer)
sns.jointplot(x="brewery.brewery_id", y="beer.auth_rating", data=my_beer_df, kind='reg', color='blue', size=8);

# %% [markdown]
# ## Ratings by brewery also wildly vary and there is little-to-no correlation to my ratings.

# %% [markdown]
# ## Finally, let's check if the beer style influences my ratings

# %%
# Let's use OLS to check how if the beer style correlates to my ratings
from statsmodels.formula.api import ols
y = my_beer_df['beer.auth_rating']
X = my_beer_df['beer.beer_style']
model = ols(formula="y ~ C(X)", data=my_beer_df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.699
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     5.419
# Date:                Thu, 18 May 2017   Prob (F-statistic):           3.18e-15
# Time:                        15:25:26   Log-Likelihood:                -67.707
# No. Observations:                 181   AIC:                             245.4
# Df Residuals:                     126   BIC:                             421.3
# Df Model:                          54
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                        4.0000      0.422      9.488      0.000       3.166       4.834
# C(X)[T.Belgian Dubbel]                          -0.5000      0.596     -0.839      0.403      -1.680       0.680
# C(X)[T.Belgian Strong Golden Ale]               -0.3750      0.516     -0.726      0.469      -1.397       0.647
# C(X)[T.Belgian Tripel]                          -0.2500      0.596     -0.419      0.676      -1.430       0.930
# C(X)[T.Blonde Ale]                           -1.207e-14      0.596  -2.02e-14      1.000      -1.180       1.180
# C(X)[T.Blonde Ale - Belgian Blonde / Golden]    -0.5000      0.596     -0.839      0.403      -1.680       0.680
# C(X)[T.Bock]                                    -1.5000      0.516     -2.905      0.004      -2.522      -0.478
# C(X)[T.Brown Ale - American]                    -0.3333      0.487     -0.685      0.495      -1.297       0.630
# C(X)[T.Cream Ale]                                1.0000      0.596      1.677      0.096      -0.180       2.180
# C(X)[T.Dunkelweizen]                            -0.4375      0.471     -0.928      0.355      -1.370       0.495
# C(X)[T.Fruit Beer]                              -1.0000      0.596     -1.677      0.096      -2.180       0.180
# C(X)[T.Golden Ale]                              -0.5000      0.516     -0.968      0.335      -1.522       0.522
# C(X)[T.Happoshu]                                -1.5000      0.516     -2.905      0.004      -2.522      -0.478
# C(X)[T.Hefeweizen]                              -0.4500      0.462     -0.974      0.332      -1.364       0.464
# C(X)[T.IPA - American]                          -0.3200      0.430     -0.744      0.458      -1.171       0.531
# C(X)[T.IPA - Belgian]                           -0.7500      0.596     -1.258      0.211      -1.930       0.430
# C(X)[T.IPA - Black / Cascadian Dark Ale]        -0.2500      0.596     -0.419      0.676      -1.430       0.930
# C(X)[T.IPA - English]                           -0.2500      0.596     -0.419      0.676      -1.430       0.930
# C(X)[T.IPA - Imperial / Double]              -5.876e-15      0.471  -1.25e-14      1.000      -0.933       0.933
# C(X)[T.IPA - Red]                            -4.127e-15      0.596  -6.92e-15      1.000      -1.180       1.180
# C(X)[T.Kellerbier / Zwickelbier]                -0.2500      0.596     -0.419      0.676      -1.430       0.930
# C(X)[T.Lager - American Amber / Red]            -0.8750      0.516     -1.695      0.093      -1.897       0.147
# C(X)[T.Lager - Dark]                            -1.2500      0.487     -2.568      0.011      -2.213      -0.287
# C(X)[T.Lager - Dunkel Munich]                   -0.2000      0.462     -0.433      0.666      -1.114       0.714
# C(X)[T.Lager - Euro]                            -1.0833      0.487     -2.225      0.028      -2.047      -0.120
# C(X)[T.Lager - Euro Dark]                     -5.55e-15      0.596  -9.31e-15      1.000      -1.180       1.180
# C(X)[T.Lager - Helles]                          -0.8333      0.487     -1.712      0.089      -1.797       0.130
# C(X)[T.Lager - Japanese Rice]                   -0.8750      0.516     -1.695      0.093      -1.897       0.147
# C(X)[T.Lager - North American Adjunct]          -1.7500      0.451     -3.883      0.000      -2.642      -0.858
# C(X)[T.Lager - Pale]                            -1.2981      0.430     -3.022      0.003      -2.148      -0.448
# C(X)[T.Lager - Vienna]                          -1.2500      0.596     -2.097      0.038      -2.430      -0.070
# C(X)[T.Märzen]                                  -0.2083      0.455     -0.458      0.648      -1.109       0.693
# C(X)[T.Pale Ale - American]                     -0.2000      0.432     -0.463      0.644      -1.055       0.655
# C(X)[T.Pale Ale - English]                      -0.5000      0.596     -0.839      0.403      -1.680       0.680
# C(X)[T.Pale Wheat Ale - American]               -0.5000      0.516     -0.968      0.335      -1.522       0.522
# C(X)[T.Pilsner - German]                        -0.8750      0.516     -1.695      0.093      -1.897       0.147
# C(X)[T.Pilsner - Other]                         -0.7500      0.596     -1.258      0.211      -1.930       0.430
# C(X)[T.Porter - American]                       -0.8750      0.516     -1.695      0.093      -1.897       0.147
# C(X)[T.Porter - Baltic]                         -1.0000      0.596     -1.677      0.096      -2.180       0.180
# C(X)[T.Porter - Imperial / Double]           -5.789e-16      0.596  -9.71e-16      1.000      -1.180       1.180
# C(X)[T.Red Ale - American Amber / Red]          -0.6250      0.455     -1.373      0.172      -1.526       0.276
# C(X)[T.Rye Beer]                                -0.2500      0.596     -0.419      0.676      -1.430       0.930
# C(X)[T.Saison / Farmhouse Ale]                  -0.1250      0.516     -0.242      0.809      -1.147       0.897
# C(X)[T.Schwarzbier]                             -0.9167      0.487     -1.883      0.062      -1.880       0.047
# C(X)[T.Scotch Ale / Wee Heavy]                  -2.5000      0.596     -4.193      0.000      -3.680      -1.320
# C(X)[T.Stout - American]                        -0.2500      0.596     -0.419      0.676      -1.430       0.930
# C(X)[T.Stout - American Imperial / Double]      -0.1250      0.516     -0.242      0.809      -1.147       0.897
# C(X)[T.Stout - Foreign / Export]                 0.0833      0.487      0.171      0.864      -0.880       1.047
# C(X)[T.Stout - Imperial / Double]               -0.2500      0.596     -0.419      0.676      -1.430       0.930
# C(X)[T.Stout - Milk / Sweet]                    -1.2500      0.596     -2.097      0.038      -2.430      -0.070
# C(X)[T.Stout - Other]                           -0.2500      0.516     -0.484      0.629      -1.272       0.772
# C(X)[T.Stout - Russian Imperial]                 0.2500      0.516      0.484      0.629      -0.772       1.272
# C(X)[T.Strong Ale - American]                   -0.3750      0.516     -0.726      0.469      -1.397       0.647
# C(X)[T.Strong Ale - English]                     0.2500      0.596      0.419      0.676      -0.930       1.430
# C(X)[T.Witbier]                                 -0.5000      0.487     -1.027      0.306      -1.463       0.463
# ==============================================================================
# Omnibus:                        8.146   Durbin-Watson:                   1.662
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):               15.601
# Skew:                          -0.002   Prob(JB):                     0.000409
# Kurtosis:                       4.438   Cond. No.                         104.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## We see a stronger correlation with the "beer style" variable, with R-squared at 0.699, it is positively correlated and our strongest predictor (at this point).

# %%
# Let's do the same thing, with brewery included this time as another var
y2 = my_beer_df['beer.auth_rating']
X2 = my_beer_df['beer.beer_style']
X2_2 = my_beer_df['brewery.brewery_name']
model2 = ols(formula="y2 ~ C(X2) + C(X2_2)", data=my_beer_df).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     y2   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.518
# Method:                 Least Squares   F-statistic:                     2.143
# Date:                Thu, 18 May 2017   Prob (F-statistic):             0.0783
# Time:                        15:32:56   Log-Likelihood:                 142.58
# No. Observations:                 181   AIC:                             54.84
# Df Residuals:                      11   BIC:                             598.6
# Df Model:                         169
# Covariance Type:            nonrobust
# ===============================================================================================================================
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------
# Intercept                                
# C(X2_2)[T.Ambev]                                               -0.6000      0.970     -0.618      0.549      -2.735       1.535
# C(X2_2)[T.Anchor Brewing Company]                               0.5667      0.598      0.948      0.364      -0.749       1.883
# C(X2_2)[T.Arcana Brewing Company]                              -0.7666      0.964     -0.795      0.443      -2.888       1.355
# C(X2_2)[T.Arrogant Brewing]                                    -0.3500      0.836     -0.418      0.684      -2.190       1.491
# C(X2_2)[T.Asahi Breweries]                                     -0.8500      0.841     -1.010      0.334      -2.701       1.001
# C(X2_2)[T.Athenian Brewery]                                    -0.8500      0.795     -1.070      0.308      -2.599       0.899
# C(X2_2)[T.Augustiner-Bräu München]                              0.6500      0.944      0.689      0.505      -1.427       2.727
# C(X2_2)[T.Avery Brewing Co.]                                    0.3167      0.590      0.537      0.602      -0.983       1.616
# C(X2_2)[T.BRLO ]                                               -0.2056      0.225     -0.915      0.380      -0.700       0.289
# C(X2_2)[T.Balter Brewing Company]                               0.9000      0.556      1.620      0.134      -0.323       2.123
# C(X2_2)[T.Bear Republic Brewing Co.]                            0.5667      0.598      0.948      0.364      -0.749       1.883
# C(X2_2)[T.Beer Here]                                            0.1694      0.225      0.754      0.467      -0.325       0.664
# C(X2_2)[T.Beijing Yanjing Brewery]                             -1.6000      0.795     -2.013      0.069      -3.349       0.149
# C(X2_2)[T.Bell's Brewery]                                       1.0667      0.842      1.266      0.232      -0.787       2.921
# C(X2_2)[T.Big Face Sörfőzde]                                    1.0667      0.842      1.266      0.232      -0.787       2.921
# C(X2_2)[T.Birra Moretti]                                       -0.3500      0.794     -0.441      0.668      -2.098       1.398
# C(X2_2)[T.Birra Peroni]                                        -1.1000      0.785     -1.401      0.189      -2.828       0.628
# C(X2_2)[T.Black Husky Brewing]                                  0.6500      0.549      1.184      0.261      -0.558       1.858
# C(X2_2)[T.Bogotá Beer Company]                                  0.3167      0.580      0.546      0.596      -0.959       1.592
# C(X2_2)[T.Boon Rawd Brewery]                                   -0.9750      0.730     -1.335      0.209      -2.583       0.633
# C(X2_2)[T.Boston Beer Company]                                  0.0222      0.371      0.060      0.953      -0.794       0.838
# C(X2_2)[T.Boston Breweries]                                    -0.3500      0.795     -0.440      0.668      -2.099       1.399
# C(X2_2)[T.Brasserie Lefebvre]                                   0.1963      0.334      0.588      0.568      -0.538       0.930
# C(X2_2)[T.Brauerei Göss]                                       -0.8500      1.107     -0.768      0.459      -3.287       1.587
# C(X2_2)[T.Brauhaus Riegele]                                     0.6500      0.943      0.689      0.505      -1.426       2.726
# C(X2_2)[T.Brouwerij Emelisse]                                   0.9834      0.753      1.306      0.218      -0.674       2.641
# C(X2_2)[T.Brouwerij Van Honsebrouck]                            0.0444      0.225      0.198      0.847      -0.450       0.539
# C(X2_2)[T.Browar Pinta]                                         0.3167      0.598      0.530      0.607      -0.999       1.633
# C(X2_2)[T.C.K. Browar]                                         -0.8500      0.735     -1.156      0.272      -2.468       0.768
# C(X2_2)[T.CODA Cerveceria Consciente]                           0.4000      0.556      0.720      0.487      -0.823       1.623
# C(X2_2)[T.Cambrew]                                             -0.3500      0.971     -0.361      0.725      -2.486       1.786
# C(X2_2)[T.Cape Brewing Co.]                                    -0.1000      0.765     -0.131      0.898      -1.784       1.584
# C(X2_2)[T.Capital Brewery]                                      0.1500      1.153      0.130      0.899      -2.387       2.687
# C(X2_2)[T.Carlton & United Breweries]                          -0.1000      0.795     -0.126      0.902      -1.849       1.649
# C(X2_2)[T.Catchment Brewing Co.]                                0.8167      0.598      1.366      0.199      -0.499       2.133
# C(X2_2)[T.Cervecería Austral]                                  -1.1000      0.995     -1.106      0.292      -3.289       1.089
# C(X2_2)[T.Cervecería Barbarian ]                                0.5667      0.594      0.954      0.360      -0.740       1.874
# C(X2_2)[T.Cervecería Bavaria]                                  -0.6000      0.811     -0.740      0.475      -2.385       1.185
# C(X2_2)[T.Cervecería Kross]                                     0.3167      1.047      0.302      0.768      -1.988       2.621
# C(X2_2)[T.Cervecería y Maltería Quilmes]                       -0.6000      0.968     -0.620      0.548      -2.731       1.531
# C(X2_2)[T.Cervejaria Petrópolis]                               -0.8500      0.825     -1.030      0.325      -2.666       0.966
# C(X2_2)[T.Chelarte S.A.S.]                                     -0.1000      0.556     -0.180      0.861      -1.323       1.123
# C(X2_2)[T.Companhia União de Cervejas de Angola]               -1.3500      0.795     -1.699      0.117      -3.099       0.399
# C(X2_2)[T.Compañia Cervecerias Unidas - CCU Chile]             -0.8500      0.795     -1.070      0.308      -2.599       0.899
# C(X2_2)[T.Crooked Can]                                          0.1500      0.500      0.300      0.770      -0.949       1.250
# C(X2_2)[T.Crooked Stave Artisan Beer Project]                   0.5667      0.598      0.948      0.364      -0.749       1.883
# C(X2_2)[T.Denver Beer Co.]                                      0.8167      0.598      1.366      0.199      -0.499       2.133
# C(X2_2)[T.Deschutes Brewery]                                    0.4834      1.149      0.421      0.682      -2.046       3.013
# C(X2_2)[T.Dogfish Head Craft Brewery]                           0.5888      0.444      1.327      0.212      -0.388       1.566
# C(X2_2)[T.Drake's Brewing Company]                              0.0296      0.334      0.089      0.931      -0.704       0.764
# C(X2_2)[T.Dreher Sörgyárak]                                    -0.2278      0.371     -0.615      0.551      -1.044       0.588
# C(X2_2)[T.Duck Foot Brewing Company]                            0.0667      0.800      0.083      0.935      -1.695       1.828
# C(X2_2)[T.Elixi Microbrewery]                                   0.0667      0.598      0.112      0.913      -1.249       1.383
# C(X2_2)[T.Erdinger Weissbräu]                                   0.6500      1.265      0.514      0.617      -2.134       3.434
# C(X2_2)[T.Fulton Beer]                                          0.8167      0.598      1.366      0.199      -0.499       2.133
# C(X2_2)[T.Goose Island Beer Co.]                                0.5667      0.861      0.658      0.524      -1.329       2.463
# C(X2_2)[T.Great Divide Brewing Company]                         0.2796      0.334      0.838      0.420      -0.454       1.014
# C(X2_2)[T.Green Flash Brewing Company]                          0.5667      0.598      0.948      0.364      -0.749       1.883
# C(X2_2)[T.Mother Earth Brew Co.]                                0.5667      0.598      0.948      0.364      -0.749       1.883
# C(X2_2)[T.New Glarus Brewing Company]                           0.7944      0.225      3.535      0.005       0.300       1.289
# C(X2_2)[T.New Terrain Brewing Co.]                              0.4000      0.830      0.482      0.639      -1.427       2.227
# C(X2_2)[T.Odell Brewing Co.]                                    0.6500      0.556      1.170      0.267      -0.573       1.873
# C(X2_2)[T.Olympic Brewery]                                     -0.9750      0.730     -1.335      0.209      -2.583       0.633
# C(X2_2)[T.Otaru Beer]                                           0.1500      1.265      0.119      0.908      -2.634       2.934
# C(X2_2)[T.Otro Mundo Brewing Company (CCU Argentina)]          -0.6000      1.044     -0.575      0.577      -2.898       1.698
# C(X2_2)[T.PT Multi Bintang Indonesia Tbk.]                     -0.0806      0.225     -0.359      0.727      -0.575       0.414
# C(X2_2)[T.ParrotDog]                                            0.8167      0.842      0.970      0.353      -1.037       2.671
# C(X2_2)[T.Passauer Bullenbier]                                  0.0222      0.371      0.060      0.953      -0.794       0.838
# C(X2_2)[T.Paulaner Brauerei]                                    0.4000      1.107      0.361      0.725      -2.037       2.837
# C(X2_2)[T.Pivovar Velké Popovice]                              -1.3500      1.173     -1.150      0.274      -3.933       1.233
# C(X2_2)[T.Pivovarna Laško]                                      0.2944      0.225      1.310      0.217      -0.200       0.789
# C(X2_2)[T.Prost Brewing Company]                               -0.3500      0.944     -0.371      0.718      -2.427       1.727
# C(X2_2)[T.Renaissance Brewing Company]                         -0.9556      0.225     -4.252      0.001      -1.450      -0.461
# C(X2_2)[T.Sabeco]                                              -1.0375      0.696     -1.491      0.164      -2.569       0.495
# C(X2_2)[T.Sail & Anchor]                                        0.8167      0.840      0.972      0.352      -1.032       2.665
# C(X2_2)[T.Saint Archer Brewing Company]                         0.4000      0.556      0.720      0.487      -0.823       1.623
# C(X2_2)[T.San Biagio]                                          -0.0537      0.334     -0.161      0.875      -0.788       0.680
# C(X2_2)[T.Santorini Brewing Co.]                                0.2944      0.225      1.310      0.217      -0.200       0.789
# C(X2_2)[T.Sapporo Breweries]                                   -0.1000      0.563     -0.178      0.862      -1.338       1.138
# C(X2_2)[T.Shanghai Brewery]                                     0.5667      0.598      0.948      0.364      -0.749       1.883
# C(X2_2)[T.Sherpa House]                                        -0.2666      1.149     -0.232      0.821      -2.796       2.263
# C(X2_2)[T.Soproni Sörgyár (Heineken Hungária)]                 -0.8500      0.795     -1.070      0.308      -2.599       0.899
# C(X2_2)[T.South African Breweries]                             -1.1000      0.795     -1.384      0.194      -2.849       0.649
# C(X2_2)[T.Spaten-Franziskaner-Löwenbräu-Gruppe]                 0.9000      0.928      0.970      0.353      -1.142       2.942
# C(X2_2)[T.Squatters Craft Beers]                                0.0296      0.334      0.089      0.931      -0.704       0.764
# C(X2_2)[T.Staatliches Hofbräuhaus München]                      0.6500      0.765      0.849      0.414      -1.034       2.334
# C(X2_2)[T.Steamworks Brewing Co. (Colorado)]                    0.4000      0.556      0.720      0.487      -0.823       1.623
# C(X2_2)[T.Stone & Wood]                                         0.1694      0.225      0.754      0.467      -0.325       0.664
# C(X2_2)[T.Stone Brewing]                                       -0.1000      0.555     -0.180      0.860      -1.322       1.122
# C(X2_2)[T.Terrapin Beer Co. ]                                   0.3167      0.598      0.530      0.607      -0.999       1.633
# C(X2_2)[T.Thai Beverage PLC]                                   -1.1000      0.795     -1.384      0.194      -2.849       0.649
# C(X2_2)[T.The Sprig & Fern Brewery]                             0.4000      1.265      0.316      0.758      -2.384       3.184
# C(X2_2)[T.Toppling Goliath Brewing Co.]                         1.6500      0.556      2.969      0.013       0.427       2.873
# C(X2_2)[T.United Breweries (India)]                            -0.8500      0.971     -0.876      0.400      -2.986       1.286
# C(X2_2)[T.Upslope Brewing Company]                              0.4000      0.556      0.720      0.487      -0.823       1.623
# C(X2_2)[T.Volcanes del Sur]                                    -0.8037      0.334     -2.410      0.035      -1.538      -0.070
# C(X2_2)[T.Westbrook Brewing Co.]                                0.1500      0.663      0.226      0.825      -1.309       1.609
# C(X2_2)[T.Yo-Ho Brewing Company]                                0.4000      0.421      0.951      0.362      -0.525       1.326
# C(X2_2)[T.ZEOS Brewing]                                        -0.3500      0.795     -0.440      0.668      -2.099       1.399
# ==============================================================================
# Omnibus:                       93.748   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39577.532
# Skew:                           0.024   Prob(JB):                         0.00
# Kurtosis:                      75.442   Cond. No.                     2.38e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 3.43e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Interesting to note that when brewery is included, the R-squared jumps to 0.971!!! Not to get too excited, because our Adj. R-squared actually is worse, so we have crossed into over-fitting territory.

# %%
# Let's do the same thing, with brewery included this time as another var
y3 = my_beer_df['beer.auth_rating']
X3 = my_beer_df['beer.beer_style']
X3_3 = my_beer_df['brewery.country_name'] 
model3 = ols(formula="y3 ~ C(X3) + C(X3_3)", data=my_beer_df).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     y3   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                     5.214
# Date:                Thu, 18 May 2017   Prob (F-statistic):           1.92e-14
# Time:                        15:45:22   Log-Likelihood:                -24.378
# No. Observations:                 181   AIC:                             214.8
# Df Residuals:                      98   BIC:                             480.2
# Df Model:                          82
# Covariance Type:            nonrobust
# =================================================================================================================
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                         3.2441      0.557      5.822      0.000       2.138       4.350
# C(X3)[T.Belgian Dubbel]                          -0.5000      0.532     -0.940      0.350      -1.556       0.556
# C(X3)[T.Belgian Strong Golden Ale]               -0.3268      0.603     -0.542      0.589      -1.524       0.870
# C(X3)[T.Belgian Tripel]                          -0.5016      0.558     -0.899      0.371      -1.609       0.606
# C(X3)[T.Blonde Ale]                               0.2938      0.567      0.518      0.605      -0.831       1.419
# C(X3)[T.Blonde Ale - Belgian Blonde / Golden]    -0.5768      0.804     -0.717      0.475      -2.173       1.020
# C(X3)[T.Bock]                                    -1.1508      0.494     -2.328      0.022      -2.132      -0.170
# C(X3)[T.Brown Ale - American]                    -0.3333      0.434     -0.767      0.445      -1.196       0.529
# C(X3)[T.Cream Ale]                                1.0000      0.532      1.879      0.063      -0.056       2.056
# C(X3)[T.Dunkelweizen]                            -0.9699      0.448     -2.164      0.033      -1.860      -0.080
# C(X3)[T.Fruit Beer]                              -0.8268      0.603     -1.370      0.174      -2.024       0.370
# C(X3)[T.Golden Ale]                              -0.4546      0.487     -0.933      0.353      -1.421       0.512
# C(X3)[T.Happoshu]                                -1.6930      0.486     -3.480      0.001      -2.658      -0.728
# C(X3)[T.Hefeweizen]                              -0.5634      0.426     -1.324      0.189      -1.408       0.281
# C(X3)[T.IPA - American]                          -0.2553      0.386     -0.661      0.510      -1.021       0.511
# C(X3)[T.IPA - Belgian]                           -0.7500      0.532     -1.409      0.162      -1.806       0.306
# C(X3)[T.IPA - Black / Cascadian Dark Ale]        -0.5833      0.687     -0.849      0.398      -1.947       0.780
# C(X3)[T.IPA - English]                           -0.2500      0.532     -0.470      0.640      -1.306       0.806
# C(X3)[T.IPA - Imperial / Double]                 -0.0833      0.434     -0.192      0.848      -0.946       0.779
# C(X3)[T.IPA - Red]                             5.551e-17      0.532   1.04e-16      1.000      -1.056       1.056
# C(X3)[T.Kellerbier / Zwickelbier]                -1.0462      0.566     -1.847      0.068      -2.170       0.078
# C(X3)[T.Lager - American Amber / Red]            -0.7902      0.468     -1.689      0.094      -1.719       0.138
# C(X3)[T.Lager - Dark]                            -0.6576      0.579     -1.135      0.259      -1.807       0.492
# C(X3)[T.Lager - Dunkel Munich]                   -0.6065      0.434     -1.397      0.165      -1.468       0.255
# C(X3)[T.Lager - Euro]                            -0.9922      0.507     -1.959      0.053      -1.997       0.013
# C(X3)[T.Lager - Euro Dark]                        0.3779      0.336      1.124      0.264      -0.289       1.045
# C(X3)[T.Lager - Helles]                          -1.1377      0.450     -2.530      0.013      -2.030      -0.245
# C(X3)[T.Lager - Japanese Rice]                   -1.0680      0.486     -2.196      0.030      -2.033      -0.103
# C(X3)[T.Lager - North American Adjunct]          -1.3979      0.437     -3.196      0.002      -2.266      -0.530
# C(X3)[T.Lager - Pale]                            -0.9941      0.411     -2.419      0.017      -1.810      -0.178
# C(X3)[T.Lager - Vienna]                          -0.9058      0.567     -1.598      0.113      -2.030       0.219
# C(X3)[T.Märzen]                                  -0.6370      0.440     -1.446      0.151      -1.511       0.237
# C(X3)[T.Pale Ale - American]                     -0.1961      0.388     -0.505      0.614      -0.966       0.574
# C(X3)[T.Pale Ale - English]                      -0.4339      0.592     -0.733      0.465      -1.609       0.741
# C(X3)[T.Pale Wheat Ale - American]               -0.5018      0.487     -1.031      0.305      -1.467       0.464
# C(X3)[T.Pilsner - German]                        -0.9715      0.467     -2.079      0.040      -1.899      -0.044
# C(X3)[T.Pilsner - Other]                          0.0029      0.336      0.009      0.993      -0.664       0.670
# C(X3)[T.Porter - American]                       -0.8750      0.461     -1.899      0.061      -1.789       0.039
# C(X3)[T.Porter - Baltic]                         -1.7962      0.566     -3.172      0.002      -2.920      -0.672
# C(X3)[T.Porter - Imperial / Double]           -1.866e-15      0.532  -3.51e-15      1.000      -1.056       1.056
# C(X3)[T.Red Ale - American Amber / Red]          -0.7186      0.420     -1.710      0.090      -1.552       0.115
# C(X3)[T.Rye Beer]                                -0.2500      0.532     -0.470      0.640      -1.306       0.806
# C(X3)[T.Saison / Farmhouse Ale]                  -0.2215      0.467     -0.474      0.637      -1.149       0.706
# C(X3)[T.Schwarzbier]                             -0.7191      0.466     -1.543      0.126      -1.644       0.206
# C(X3)[T.Scotch Ale / Wee Heavy]                  -2.8443      0.619     -4.595      0.000      -4.073      -1.616
# C(X3)[T.Stout - American]                        -0.2500      0.532     -0.470      0.640      -1.306       0.806
# C(X3)[T.Stout - American Imperial / Double]      -0.1250      0.461     -0.271      0.787      -1.039       0.789
# C(X3)[T.Stout - Foreign / Export]                -0.0117      0.477     -0.025      0.980      -0.957       0.934
# C(X3)[T.Stout - Imperial / Double]               -0.2500      0.532     -0.470      0.640      -1.306       0.806
# C(X3)[T.Stout - Milk / Sweet]                    -0.8085      0.630     -1.284      0.202      -2.058       0.441
# C(X3)[T.Stout - Other]                           -0.2500      0.461     -0.543      0.589      -1.164       0.664
# C(X3)[T.Stout - Russian Imperial]                 0.2500      0.461      0.543      0.589      -0.664       1.164
# C(X3)[T.Strong Ale - American]                   -0.2902      0.468     -0.620      0.537      -1.219       0.638
# C(X3)[T.Strong Ale - English]                     0.2500      0.532      0.470      0.640      -0.806       1.306
# C(X3)[T.Witbier]                                 -0.6287      0.447     -1.407      0.162      -1.515       0.258
# C(X3_3)[T.Argentina]                              0.5862      0.431      1.359      0.177      -0.270       1.442
# C(X3_3)[T.Australia]                              1.0074      0.424      2.373      0.020       0.165       1.850
# C(X3_3)[T.Austria]                                0.1428      0.596      0.240      0.811      -1.039       1.325
# C(X3_3)[T.Belgium]                                0.8327      0.695      1.198      0.234      -0.547       2.212
# C(X3_3)[T.Brazil]                                 0.3144      0.513      0.613      0.541      -0.704       1.332
# C(X3_3)[T.Cambodia]                               0.6538      0.582      1.123      0.264      -0.501       1.809
# C(X3_3)[T.Chile]                                  0.4134      0.439      0.943      0.348      -0.457       1.284
# C(X3_3)[T.China / People's Republic of China]     0.2556      0.468      0.546      0.586      -0.674       1.185
# C(X3_3)[T.Colombia]                               0.4117      0.439      0.939      0.350      -0.459       1.282
# C(X3_3)[T.Czech Republic]                         0.0384      0.636      0.060      0.952      -1.224       1.301
# C(X3_3)[T.Denmark]                                1.0892      0.598      1.821      0.072      -0.098       2.276
# C(X3_3)[T.France]                                 0.9980      0.622      1.606      0.112      -0.235       2.232
# C(X3_3)[T.Germany]                                1.5521      0.443      3.503      0.001       0.673       2.431
# C(X3_3)[T.Greece]                                 0.4621      0.410      1.127      0.263      -0.352       1.276
# C(X3_3)[T.Hong Kong]                              1.0112      0.557      1.814      0.073      -0.095       2.117
# C(X3_3)[T.Hungary]                                0.8727      0.455      1.917      0.058      -0.031       1.776
# C(X3_3)[T.India]                                  0.1538      0.582      0.264      0.792      -1.001       1.309
# C(X3_3)[T.Indonesia]                              0.0029      0.336      0.009      0.993      -0.664       0.670
# C(X3_3)[T.Italy]                                  0.5827      0.447      1.302      0.196      -0.305       1.471
# C(X3_3)[T.Japan]                                  0.9489      0.422      2.249      0.027       0.112       1.786
# C(X3_3)[T.Netherlands]                            1.0176      0.620      1.642      0.104      -0.212       2.247
# C(X3_3)[T.New Zealand]                            1.1001      0.505      2.177      0.032       0.097       2.103
# C(X3_3)[T.Peru]                                   0.7594      0.512      1.484      0.141      -0.256       1.775
# C(X3_3)[T.Poland]                                 0.3999      0.456      0.876      0.383      -0.506       1.306
# C(X3_3)[T.Singapore]                              0.5000      0.532      0.940      0.350      -0.556       1.556
# C(X3_3)[T.Slovenia]                               0.3779      0.336      1.124      0.264      -0.289       1.045
# C(X3_3)[T.South Africa]                           0.6898      0.441      1.564      0.121      -0.185       1.565
# C(X3_3)[T.Thailand]                               0.3333      0.434      0.767      0.445      -0.529       1.196
# C(X3_3)[T.United States]                          0.7559      0.411      1.839      0.069      -0.060       1.572
# C(X3_3)[T.Vietnam]                                0.2949      0.397      0.742      0.460      -0.494       1.084
# ==============================================================================
# Omnibus:                       21.745   Durbin-Watson:                   1.808
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.475
# Skew:                           0.264   Prob(JB):                     4.53e-19
# Kurtosis:                       6.305   Cond. No.                     1.96e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.81e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Here we are looking to see if country of production introduces any benefit to the model. Overall the R-squared is lower than model2, however, the Adj. R-squared is actually greatest in this version. We will continue this exploration once we get to the machine learning section of the course.

# %% [markdown]
# # 2. Is there a significant difference between my individual set of beer ratings when compared to the average user? If yes/no, what does this mean for future prediction methodologies?

# %%
#This looks to be of the most interest, given I am curious how different my ratings are compared to the avg user
my_beer_df[['beer.auth_rating', 'beer.rating_score']].describe()
# Out:
#        beer.auth_rating  beer.rating_score
# count        181.000000         181.000000
# mean           3.392265           3.438840
# std            0.642906           0.398313
# min            1.500000           2.319000
# 25%            3.000000           3.168000
# 50%            3.500000           3.537000
# 75%            3.750000           3.729000
# max            5.000000           4.560000

# %%
#let's visualize my ratings vs the avg user
sns.jointplot(x="beer.auth_rating", y="beer.rating_score", data=my_beer_df, kind='reg', color='green', size=8);

# %% [markdown]
# ## Run a Two-sided T-test with the following hypotheses:
# Null hypothesis: mean of my beer ratings = mean of avg user beer ratings
#
# Alternate hypothesis: mean of my beer ratings != mean of avg user beer ratings

# %%
#leverage the Python stats package for ease
stats.ttest_ind(my_beer_df['beer.auth_rating'], my_beer_df['beer.rating_score'])
# Out:
# Ttest_indResult(statistic=-0.82850869202138933, pvalue=0.40793141463231308)

# %% [markdown]
# ## Interesting results. Given the high p-value: 0.41 I cannot reject the null hypothesis that the means of my ratings and the average user are different.
