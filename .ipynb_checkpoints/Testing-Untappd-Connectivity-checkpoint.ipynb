# %%
#Testing connectivity with Untappd API
import requests #for requesting API calls
import pandas as pd #for building pandas dataframes for analysis
from pandas.io.json import json_normalize #help with converting dictionaries to dataframes
# %matplotlib inline 
import datetime # for tracking API call counts
import seaborn as sns #for cool visulizations
# Out:
# /Users/joshuaemayer/anaconda/envs/python3/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
# Assign URL to variable: url
url = 'https://api.untappd.com/v4' #base URL for all API calls
client_id = '?client_id=D9E63A3F203F8A4FDBE5B7E58CEDB2E90FF50AB4'
client_secret = '&client_secret=C861E23878359F93F1EF3FDB7F233095316C6CA5'
code='F1BD60BFBB99F5AA8D23067359210F6370EEE57E'
access_token = '51CDCC3DAECC020BA92A9D959963D27D5D1DA951'

# %%
#Parameters specific to user beer
user_beer = '/user/beers'
username = '/joshuaemayer' #return results for this user
limit = '&limit='
limit_num = 50
offset = '&offset='
offset_num = 0

# %%
#Let's keep track of how many API calls we are making for fun
api_count = []

# %%
# Package the request, send the request and catch the response: r
r = requests.get(url+user_beer+username+client_id+client_secret+limit+str(limit_num)+offset+str(offset_num))
api_count.append(format(datetime.datetime.now()))

# %%
api_count
# Out:
# ['2017-04-13 22:01:46.996263', '2017-04-13 22:13:34.879621']

# %%
type(r)
# Out:
# requests.models.Response

# %%
# Decode the JSON data into a dictionary: json_data
json_data = r.json()

# %%
type(json_data)
# Out:
# dict

# %%
json_data
# Out:
# {'meta': {'code': 200,
#   'init_time': {'measure': 'seconds', 'time': 0.007},
#   'response_time': {'measure': 'seconds', 'time': 0.033}},
#  'notifications': [],
#  'response': {'beers': {'count': 0,
#    'items': [],
#    'sort_english': 'Date (New to Old)',
#    'sort_name': 'Date (New to Old)'},
#   'brewery_id': False,
#   'container_id': False,
#   'country_id': False,
#   'dates': {'end_date': False,
#    'first_checkin_date': 'Fri, 01 Apr 2016 18:32:32 +0000',
#    'start_date': False},
#   'is_search': False,
#   'sort': False,
#   'sort_key': 'date',
#   'sort_name': 'Date (New to Old)',
#   'total_count': 202,
#   'type_id': False}}

# %%
json_data['response']['beers']['items']
# Out:
# [{'beer': {'auth_rating': 3.75,
#    'beer_abv': 6,
#    'beer_description': '',
#    'beer_ibu': 65,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-_26294_b5d54cb5876227cb9b364a126946.jpeg',
#    'beer_name': 'Third Eye Pale Ale',
#    'beer_slug': 'steamworks-brewing-co-third-eye-pale-ale',
#    'beer_style': 'Pale Ale - American',
#    'bid': 26294,
#    'created_at': 'Sun, 23 Jan 2011 23:07:48 +0000',
#    'rating_count': 2170,
#    'rating_score': 3.606,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 4410,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-SteamworksBrewingCo_4410.jpeg',
#    'brewery_name': 'Steamworks Brewing Co. (Colorado)',
#    'brewery_slug': 'steamworks-brewing-co-colorado',
#    'contact': {'facebook': 'http://www.facebook.com/steamworksbrewing',
#     'instagram': 'steamworksbrewing',
#     'twitter': 'Stmworks',
#     'url': 'http://steamworksbrewing.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Durango',
#     'brewery_state': 'CO',
#     'lat': 37.2724,
#     'lng': -107.88}},
#   'count': 1,
#   'first_checkin_id': 439757467,
#   'first_created_at': 'Thu, 13 Apr 2017 18:02:08 -0600',
#   'first_had': 'Thu, 13 Apr 2017 18:02:08 -0600',
#   'rating_score': 3.75,
#   'recent_checkin_id': 439757467,
#   'recent_created_at': 'Thu, 13 Apr 2017 18:02:08 -0600',
#   'recent_created_at_timezone': '-6'},
#  {'beer': {'auth_rating': 4,
#    'beer_abv': 5.3,
#    'beer_description': "Each year we select the rock-star hops of the harvest to craft this bold, juicy, tropcially hop-forward brew, drumming up a citrus inspired rhythm for what's to come.",
#    'beer_ibu': 40,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-1600793_53215_sm.jpeg',
#    'beer_name': 'Drumroll APA',
#    'beer_slug': 'odell-brewing-co-drumroll-apa',
#    'beer_style': 'Pale Ale - American',
#    'bid': 1600793,
#    'created_at': 'Mon, 13 Jun 2016 19:08:49 +0000',
#    'rating_count': 20391,
#    'rating_score': 3.812,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 7296,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-OdellBrewingCo_7296.jpeg',
#    'brewery_name': 'Odell Brewing Co.',
#    'brewery_slug': 'odell-brewing-co',
#    'contact': {'facebook': 'http://www.facebook.com/OdellBrewingCo?ref=ts',
#     'instagram': '@odellbrewing',
#     'twitter': 'OdellBrewing',
#     'url': 'http://odellbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Fort Collins',
#     'brewery_state': 'CO',
#     'lat': 40.5888,
#     'lng': -105.062}},
#   'count': 1,
#   'first_checkin_id': 438862237,
#   'first_created_at': 'Mon, 10 Apr 2017 17:50:43 -0600',
#   'first_had': 'Mon, 10 Apr 2017 17:50:43 -0600',
#   'rating_score': 4,
#   'recent_checkin_id': 438862237,
#   'recent_created_at': 'Mon, 10 Apr 2017 17:50:43 -0600',
#   'recent_created_at_timezone': '-6'},
#  {'beer': {'auth_rating': 3.5,
#    'beer_abv': 5.5,
#    'beer_description': 'American Brown\nWith Cocoa & Coffee',
#    'beer_ibu': 27,
#    'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#    'beer_name': 'Java Bound',
#    'beer_slug': 'new-terrain-brewing-co-java-bound',
#    'beer_style': 'Brown Ale - American',
#    'bid': 1751883,
#    'created_at': 'Tue, 27 Sep 2016 20:47:52 +0000',
#    'rating_count': 122,
#    'rating_score': 3.801,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 299073,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-299073_dcc67.jpeg',
#    'brewery_name': 'New Terrain Brewing Co.',
#    'brewery_slug': 'new-terrain-brewing-co',
#    'contact': {'facebook': 'https://www.facebook.com/newterrainbrewing/',
#     'instagram': 'newterrainbrewingco',
#     'twitter': 'newterrainbrew',
#     'url': 'http://newterrainbrewing.com/home'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Golden',
#     'brewery_state': 'CO',
#     'lat': 39.7796,
#     'lng': -105.186}},
#   'count': 1,
#   'first_checkin_id': 438843895,
#   'first_created_at': 'Mon, 10 Apr 2017 17:00:40 -0600',
#   'first_had': 'Mon, 10 Apr 2017 17:00:40 -0600',
#   'rating_score': 3.5,
#   'recent_checkin_id': 438843895,
#   'recent_created_at': 'Mon, 10 Apr 2017 17:00:40 -0600',
#   'recent_created_at_timezone': '-6'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 5.5,
#    'beer_description': 'One Claw is a rye pale ale made with a heavy handful of malted rye and scoops of our favorite hop varieties. One Claw is dedicated to those who bring a Westbrook home, to a friend’s, or anywhere a delicious beer is needed. Cheers to you, fellow One Claw! Hopped with Amarillo, Nelson Sauvin, and Citra.',
#    'beer_ibu': 52,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-_371158_sm_6c4ec057faae480563e438c808b09a.jpeg',
#    'beer_name': 'One Claw',
#    'beer_slug': 'westbrook-brewing-co-one-claw',
#    'beer_style': 'Rye Beer',
#    'bid': 371158,
#    'created_at': 'Fri, 24 May 2013 16:21:13 +0000',
#    'rating_count': 30504,
#    'rating_score': 3.792,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 10905,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-10905_a3666.jpeg',
#    'brewery_name': 'Westbrook Brewing Co.',
#    'brewery_slug': 'westbrook-brewing-co',
#    'contact': {'facebook': 'http://www.facebook.com/pages/Westbrook-Brewing-Company/327659622509',
#     'instagram': 'westbrookbrewingco',
#     'twitter': 'westbrookbeer',
#     'url': 'http://www.westbrookbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Mt Pleasant',
#     'brewery_state': 'SC',
#     'lat': 32.8467,
#     'lng': -79.8768}},
#   'count': 1,
#   'first_checkin_id': 437868644,
#   'first_created_at': 'Sat, 08 Apr 2017 16:39:47 -0400',
#   'first_had': 'Sat, 08 Apr 2017 16:39:47 -0400',
#   'rating_score': 3.75,
#   'recent_checkin_id': 437868644,
#   'recent_created_at': 'Sat, 08 Apr 2017 16:39:47 -0400',
#   'recent_created_at_timezone': '-4'},
#  {'beer': {'auth_rating': 3.5,
#    'beer_abv': 5,
#    'beer_description': '',
#    'beer_ibu': 16,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-WhiteThai_15894.jpeg',
#    'beer_name': 'White Thai',
#    'beer_slug': 'westbrook-brewing-co-white-thai',
#    'beer_style': 'Witbier',
#    'bid': 15894,
#    'created_at': 'Tue, 21 Dec 2010 12:01:42 +0000',
#    'rating_count': 28869,
#    'rating_score': 3.572,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 10905,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-10905_a3666.jpeg',
#    'brewery_name': 'Westbrook Brewing Co.',
#    'brewery_slug': 'westbrook-brewing-co',
#    'contact': {'facebook': 'http://www.facebook.com/pages/Westbrook-Brewing-Company/327659622509',
#     'instagram': 'westbrookbrewingco',
#     'twitter': 'westbrookbeer',
#     'url': 'http://www.westbrookbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Mt Pleasant',
#     'brewery_state': 'SC',
#     'lat': 32.8467,
#     'lng': -79.8768}},
#   'count': 1,
#   'first_checkin_id': 437864480,
#   'first_created_at': 'Sat, 08 Apr 2017 16:35:42 -0400',
#   'first_had': 'Sat, 08 Apr 2017 16:35:42 -0400',
#   'rating_score': 3.5,
#   'recent_checkin_id': 437864480,
#   'recent_created_at': 'Sat, 08 Apr 2017 16:35:42 -0400',
#   'recent_created_at_timezone': '-4'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 6.3,
#    'beer_description': 'Mosaic, El Dorado, Cascade, and Comet hops join in harmony to produce a juicy, tropical treat with a distinct, dry finish. ',
#    'beer_ibu': 68,
#    'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#    'beer_name': 'Juicy Jay',
#    'beer_slug': 'legion-brewing-juicy-j',
#    'beer_style': 'IPA - American',
#    'bid': 1354532,
#    'created_at': 'Thu, 17 Dec 2015 19:28:17 +0000',
#    'rating_count': 3447,
#    'rating_score': 3.857,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 241639,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-241639_cf86b.jpeg',
#    'brewery_name': 'Legion Brewing Company',
#    'brewery_slug': 'legion-brewing-company',
#    'contact': {'facebook': 'https://www.facebook.com/LegionBrewing/',
#     'instagram': '',
#     'twitter': 'LegionBrewing',
#     'url': 'http://www.legionbrewing.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Charlotte',
#     'brewery_state': 'NC',
#     'lat': 35.2184,
#     'lng': -80.813}},
#   'count': 1,
#   'first_checkin_id': 437148487,
#   'first_created_at': 'Fri, 07 Apr 2017 16:54:29 -0400',
#   'first_had': 'Fri, 07 Apr 2017 16:54:29 -0400',
#   'rating_score': 3.75,
#   'recent_checkin_id': 437148487,
#   'recent_created_at': 'Fri, 07 Apr 2017 16:54:29 -0400',
#   'recent_created_at_timezone': '-4'},
#  {'beer': {'auth_rating': 3.25,
#    'beer_abv': 5.1,
#    'beer_description': 'A golden pale having a slightly malty body balanced by an assertive American hop flavor. This pale ale displays a delicate hop nose due to the process of dry hopping. A crisp and refreshing beer perfect for any occasion.\n\nIBU: 24\nAlcohol content: 5.2% by volume\nHops: Chinook and Cascade\n\nCalories per 12 oz. 170.1\nCarbs per 12 oz. 15.65',
#    'beer_ibu': 24,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-_4465_sm_a57decf495bac0554aaf8954eaa8aa.jpeg',
#    'beer_name': "St. Terese's Pale Ale",
#    'beer_slug': 'highland-brewing-company-st-terese-s-pale-ale',
#    'beer_style': 'Pale Ale - American',
#    'bid': 4465,
#    'created_at': 'Sat, 21 Aug 2010 09:26:35 +0000',
#    'rating_count': 15412,
#    'rating_score': 3.503,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 658,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-HighlandBrewingCo_658.jpeg',
#    'brewery_name': 'Highland Brewing Company',
#    'brewery_slug': 'highland-brewing-company',
#    'contact': {'facebook': 'https://www.facebook.com/HighlandBrewingCompany',
#     'instagram': 'HighlandBrewing',
#     'twitter': 'highlandbrews',
#     'url': 'http://www.highlandbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Asheville',
#     'brewery_state': 'NC',
#     'lat': 35.5711,
#     'lng': -82.4982}},
#   'count': 1,
#   'first_checkin_id': 437147058,
#   'first_created_at': 'Fri, 07 Apr 2017 16:52:28 -0400',
#   'first_had': 'Fri, 07 Apr 2017 16:52:28 -0400',
#   'rating_score': 3.25,
#   'recent_checkin_id': 437147058,
#   'recent_created_at': 'Fri, 07 Apr 2017 16:52:28 -0400',
#   'recent_created_at_timezone': '-4'},
#  {'beer': {'auth_rating': 4.5,
#    'beer_abv': 10,
#    'beer_description': 'This hauntingly good brew in your hand is rife with dark complexities. Seven malts were used to create deep flavors of coffee, chocolate, caramel, and molasses. A hint of bitterness and herbal character from carefully selected European and American hops help support the monolithic maltiness. A truly decadent brew that is intended to be poured into your favorite snifter and given time to warm up from its dark and cool resting place.',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-14964_c4262_sm.jpeg',
#    'beer_name': 'Dark Apparition',
#    'beer_slug': 'jackie-o-s-pub-and-brewery-dark-apparition',
#    'beer_style': 'Stout - Russian Imperial',
#    'bid': 14964,
#    'created_at': 'Thu, 16 Dec 2010 11:39:58 +0000',
#    'rating_count': 15281,
#    'rating_score': 4.127,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 5083,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-JackieOsPubBrewery_5083.jpeg',
#    'brewery_name': "Jackie O's Pub & Brewery",
#    'brewery_slug': 'jackie-o-s-pub-brewery',
#    'contact': {'facebook': 'http://www.facebook.com/JackieOsBrewery',
#     'instagram': 'jackieosbrewery',
#     'twitter': 'jackieosbrewery',
#     'url': 'http://www.jackieos.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Athens',
#     'brewery_state': 'OH',
#     'lat': 39.3276,
#     'lng': -82.1023}},
#   'count': 1,
#   'first_checkin_id': 436893982,
#   'first_created_at': 'Thu, 06 Apr 2017 22:11:34 -0400',
#   'first_had': 'Thu, 06 Apr 2017 22:11:34 -0400',
#   'rating_score': 4.5,
#   'recent_checkin_id': 436893982,
#   'recent_created_at': 'Thu, 06 Apr 2017 22:11:34 -0400',
#   'recent_created_at_timezone': '-4'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 6.2,
#    'beer_description': 'It’s all about choosing a dream. Once the decision was made to open a brewery, we knew there could be no more appropriate a name for our founding beer. We combined three hop varieties over a ninety minute boil in three separate additions and a massive amount of hops added for the dry-hop. The smooth malt profile lets the hops do the talking. It’s complex and intricate, yet completely accessible - a labor of love to be shared with the world.',
#    'beer_ibu': 60,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-151412_05a8e_sm.jpeg',
#    'beer_name': 'Really Cool Waterslides IPA',
#    'beer_slug': '3-sheeps-brewing-company-really-cool-waterslides-ipa',
#    'beer_style': 'IPA - American',
#    'bid': 151412,
#    'created_at': 'Wed, 28 Mar 2012 18:32:18 +0000',
#    'rating_count': 16012,
#    'rating_score': 3.612,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 27118,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-27118_10938.jpeg',
#    'brewery_name': '3 Sheeps Brewing Company',
#    'brewery_slug': '3-sheeps-brewing-company',
#    'contact': {'facebook': 'https://www.facebook.com/3sheeps',
#     'instagram': '3sheepsbrewing',
#     'twitter': '3sheepsbrewing',
#     'url': 'http://www.3sheepsbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Sheboygan',
#     'brewery_state': 'WI',
#     'lat': 43.7596,
#     'lng': -87.7218}},
#   'count': 1,
#   'first_checkin_id': 436512018,
#   'first_created_at': 'Wed, 05 Apr 2017 18:33:40 -0500',
#   'first_had': 'Wed, 05 Apr 2017 18:33:40 -0500',
#   'rating_score': 3.75,
#   'recent_checkin_id': 436512018,
#   'recent_created_at': 'Wed, 05 Apr 2017 18:33:40 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 6.5,
#    'beer_description': 'American Rye Stout',
#    'beer_ibu': 29,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-602114_29313_sm.jpeg',
#    'beer_name': 'Cashmere Hammer',
#    'beer_slug': '3-sheeps-brewing-company-cashmere-hammer',
#    'beer_style': 'Stout - American',
#    'bid': 602114,
#    'created_at': 'Fri, 28 Feb 2014 12:12:58 +0000',
#    'rating_count': 9862,
#    'rating_score': 3.847,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 27118,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-27118_10938.jpeg',
#    'brewery_name': '3 Sheeps Brewing Company',
#    'brewery_slug': '3-sheeps-brewing-company',
#    'contact': {'facebook': 'https://www.facebook.com/3sheeps',
#     'instagram': '3sheepsbrewing',
#     'twitter': '3sheepsbrewing',
#     'url': 'http://www.3sheepsbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Sheboygan',
#     'brewery_state': 'WI',
#     'lat': 43.7596,
#     'lng': -87.7218}},
#   'count': 1,
#   'first_checkin_id': 436226545,
#   'first_created_at': 'Tue, 04 Apr 2017 17:03:46 -0500',
#   'first_had': 'Tue, 04 Apr 2017 17:03:46 -0500',
#   'rating_score': 3.75,
#   'recent_checkin_id': 436226545,
#   'recent_created_at': 'Tue, 04 Apr 2017 17:03:46 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 4,
#    'beer_abv': 7,
#    'beer_description': "Originally brewed as a one-off in celebration of the 300th batch at our original Minneapolis brewery, 300 was so well received we had to bring it back every year. It's an IPA built on a base of Weyermann Pilsner malt and heavily hopped from start to finish with Mosaic, one of our favorite -- and unfortunately nearly impossible to find -- hop varieties. At 74 IBU and just under 7% ABV, 300 is pure hop candy and brewed in only a small quantity each year, so get it while you can. ",
#    'beer_ibu': 74,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-494653_05eb8_sm.jpeg',
#    'beer_name': '300',
#    'beer_slug': 'fulton-beer-300',
#    'beer_style': 'IPA - American',
#    'bid': 494653,
#    'created_at': 'Sat, 02 Nov 2013 19:00:16 +0000',
#    'rating_count': 12208,
#    'rating_score': 3.986,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 2314,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-FultonBeer_2314.jpeg',
#    'brewery_name': 'Fulton Beer',
#    'brewery_slug': 'fulton-beer',
#    'contact': {'facebook': 'http://www.facebook.com/FultonBeer',
#     'instagram': 'fultonbeer',
#     'twitter': 'fultonbeer',
#     'url': 'http://fultonbeer.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Minneapolis',
#     'brewery_state': 'MN',
#     'lat': 44.9849,
#     'lng': -93.279}},
#   'count': 1,
#   'first_checkin_id': 436015081,
#   'first_created_at': 'Mon, 03 Apr 2017 17:39:59 -0500',
#   'first_had': 'Mon, 03 Apr 2017 17:39:59 -0500',
#   'rating_score': 4,
#   'recent_checkin_id': 436015081,
#   'recent_created_at': 'Mon, 03 Apr 2017 17:39:59 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 5.5,
#    'beer_description': 'A blend of seven unique malts give this Brown Ale an earthy aroma and a flavor reminiscent of caramel with a slightly creamy finish. Madtown Nutbrown is available is available year-round on tap and in 12 oz. bottle 6-packs throughout Wisconsin and Illinois.',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-8049_21c10_sm.jpeg',
#    'beer_name': 'Madtown Nutbrown',
#    'beer_slug': 'ale-asylum-madtown-nutbrown',
#    'beer_style': 'Brown Ale - American',
#    'bid': 8049,
#    'created_at': 'Mon, 08 Nov 2010 12:42:17 +0000',
#    'rating_count': 12777,
#    'rating_score': 3.657,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 20,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-AleAsylum_20.jpeg',
#    'brewery_name': 'Ale Asylum',
#    'brewery_slug': 'ale-asylum',
#    'contact': {'facebook': 'http://www.facebook.com/pages/Ale-Asylum/108187444095?sk=wall&filter=1',
#     'instagram': 'ale_asylum',
#     'twitter': 'ale_asylum',
#     'url': 'http://www.aleasylum.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Madison',
#     'brewery_state': 'WI',
#     'lat': 43.1203,
#     'lng': -89.354}},
#   'count': 1,
#   'first_checkin_id': 436014503,
#   'first_created_at': 'Mon, 03 Apr 2017 17:38:06 -0500',
#   'first_had': 'Mon, 03 Apr 2017 17:38:06 -0500',
#   'rating_score': 3.75,
#   'recent_checkin_id': 436014503,
#   'recent_created_at': 'Mon, 03 Apr 2017 17:38:06 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 4.25,
#    'beer_abv': 5.3,
#    'beer_description': '',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#    'beer_name': 'Tokyo Sauna',
#    'beer_slug': 'karben4-brewing-tokyo-sauna',
#    'beer_style': 'Pale Ale - American',
#    'bid': 708077,
#    'created_at': 'Sun, 08 Jun 2014 13:19:26 +0000',
#    'rating_count': 5409,
#    'rating_score': 3.71,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 49747,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-Karben4Brewing_49747.jpeg',
#    'brewery_name': 'Karben4 Brewing',
#    'brewery_slug': 'karben4-brewing',
#    'contact': {'facebook': 'http://www.facebook.com/Karben4',
#     'instagram': 'karben4brewing',
#     'twitter': 'Karben4',
#     'url': 'http://www.karben4.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Madison',
#     'brewery_state': 'WI',
#     'lat': 43.1263,
#     'lng': -89.3257}},
#   'count': 1,
#   'first_checkin_id': 435458395,
#   'first_created_at': 'Sat, 01 Apr 2017 23:00:06 -0500',
#   'first_had': 'Sat, 01 Apr 2017 23:00:06 -0500',
#   'rating_score': 4.25,
#   'recent_checkin_id': 435458395,
#   'recent_created_at': 'Sat, 01 Apr 2017 23:00:06 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 5,
#    'beer_abv': 5.8,
#    'beer_description': 'This double dry hopped pale ale showcases the Citra hop for a well balanced beer that is delicate in body with a mild bitterness in the finish. Ferocious aromas of citrus and mango give a refreshing taste that is bright with just enough bite!',
#    'beer_ibu': 50,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-1569952_1a8a0_sm.jpeg',
#    'beer_name': 'Double Dry Hop Pseudo Sue',
#    'beer_slug': 'toppling-goliath-brewing-co-double-dry-hop-pseudo-sue',
#    'beer_style': 'Pale Ale - American',
#    'bid': 1569952,
#    'created_at': 'Tue, 24 May 2016 13:34:29 +0000',
#    'rating_count': 10006,
#    'rating_score': 4.568,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 7532,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-7532_26551.jpeg',
#    'brewery_name': 'Toppling Goliath Brewing Co.',
#    'brewery_slug': 'toppling-goliath-brewing',
#    'contact': {'facebook': 'http://www.facebook.com/TGBREWS',
#     'instagram': 'TGbrews',
#     'twitter': 'theTGBNews',
#     'url': 'http://www.tgbrews.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Decorah',
#     'brewery_state': 'IA',
#     'lat': 43.3084,
#     'lng': -91.7971}},
#   'count': 1,
#   'first_checkin_id': 435458182,
#   'first_created_at': 'Sat, 01 Apr 2017 22:59:31 -0500',
#   'first_had': 'Sat, 01 Apr 2017 22:59:31 -0500',
#   'rating_score': 5,
#   'recent_checkin_id': 435458182,
#   'recent_created_at': 'Sat, 01 Apr 2017 22:59:31 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 6.5,
#    'beer_description': 'In a sea of offerings, our most popular IPA stands\nout as one of the finest examples of a West\nCoast-style beer: Bursting with flavor and aroma,\nfinished dry, and most importantly hop-forward.\nThis beer is teeming with fruit and pine notes, and\nits light gold to blonde color make it drink like a\nsession beer.',
#    'beer_ibu': 58,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-585609_2d42c_sm.jpeg',
#    'beer_name': 'Boo Koo',
#    'beer_slug': 'mother-earth-brew-co-boo-koo',
#    'beer_style': 'IPA - American',
#    'bid': 585609,
#    'created_at': 'Mon, 10 Feb 2014 14:02:36 +0000',
#    'rating_count': 20999,
#    'rating_score': 3.853,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 5092,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-5092_b0a8b.jpeg',
#    'brewery_name': 'Mother Earth Brew Co.',
#    'brewery_slug': 'mother-earth-brew-co',
#    'contact': {'facebook': 'http://www.facebook.com/MotherEarthBrewCo',
#     'instagram': 'motherearthbrewco',
#     'twitter': 'MotherEarthBrCo',
#     'url': 'https://www.motherearthbrewco.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Vista',
#     'brewery_state': 'CA',
#     'lat': 33.1677,
#     'lng': -117.22}},
#   'count': 1,
#   'first_checkin_id': 431135621,
#   'first_created_at': 'Wed, 22 Mar 2017 17:59:17 -0700',
#   'first_had': 'Wed, 22 Mar 2017 17:59:17 -0700',
#   'rating_score': 3.75,
#   'recent_checkin_id': 431135621,
#   'recent_created_at': 'Wed, 22 Mar 2017 17:59:17 -0700',
#   'recent_created_at_timezone': '-7'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 6,
#    'beer_description': "Named after Tony Gwynn's batting average .394 during the strike shortened season.",
#    'beer_ibu': 26,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-705460_8a836_sm.jpeg',
#    'beer_name': 'San Diego Pale Ale .394',
#    'beer_slug': 'alesmith-brewing-company-san-diego-pale-ale-394',
#    'beer_style': 'Pale Ale - American',
#    'bid': 705460,
#    'created_at': 'Fri, 06 Jun 2014 18:57:29 +0000',
#    'rating_count': 25107,
#    'rating_score': 3.948,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 2471,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-2471_6bfa2.jpeg',
#    'brewery_name': 'AleSmith Brewing Company',
#    'brewery_slug': 'alesmith-brewing-company',
#    'contact': {'facebook': 'https://www.facebook.com/AleSmithBrewing',
#     'instagram': 'AleSmithBrewing',
#     'twitter': 'AleSmithBrewing',
#     'url': 'http://www.AleSmith.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'San Diego',
#     'brewery_state': 'CA',
#     'lat': 32.8883,
#     'lng': -117.15}},
#   'count': 1,
#   'first_checkin_id': 429958878,
#   'first_created_at': 'Sat, 18 Mar 2017 17:17:55 -0700',
#   'first_had': 'Sat, 18 Mar 2017 17:17:55 -0700',
#   'rating_score': 3.75,
#   'recent_checkin_id': 429958878,
#   'recent_created_at': 'Sat, 18 Mar 2017 17:17:55 -0700',
#   'recent_created_at_timezone': '-7'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 7.5,
#    'beer_description': "This hoppy American IPA is a full bodied beer brewed with American pale and crystal malts, and heavily hopped with Chinook, Cascade, Columbus and Centennial. There's a trophy in every glass.\n\n2009 Great American Beer Festival® American-Style Strong Pale Ale – GOLD\n2009 Colorado State Fair – Best of Show\n2006 Great American Beer Festival® American-Style Strong Pale Ale – SILVER\n2005 Great American Beer Festival® American-Style Strong Pale Ale – SILVER\n1999 Great American Beer Festival® India Pale Ale - GOLD",
#    'beer_ibu': 75,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-BearRepublicRacer5.jpg',
#    'beer_name': 'Racer 5 IPA®',
#    'beer_slug': 'bear-republic-brewing-co-racer-5-ipa-r',
#    'beer_style': 'IPA - American',
#    'bid': 1553,
#    'created_at': 'Sat, 21 Aug 2010 09:26:35 +0000',
#    'rating_count': 147893,
#    'rating_score': 3.885,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 94,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-bearrepublicbrewingco_94.jpeg',
#    'brewery_name': 'Bear Republic Brewing Co.',
#    'brewery_slug': 'bear-republic-brewing-co',
#    'contact': {'facebook': 'http://www.facebook.com/bearrepublic',
#     'instagram': 'bearrepublic',
#     'twitter': 'bearrepublic',
#     'url': 'http://www.bearrepublic.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Healdsburg',
#     'brewery_state': 'CA',
#     'lat': 38.6111,
#     'lng': -122.871}},
#   'count': 1,
#   'first_checkin_id': 427234588,
#   'first_created_at': 'Sat, 11 Mar 2017 18:25:36 -0800',
#   'first_had': 'Sat, 11 Mar 2017 18:25:36 -0800',
#   'rating_score': 3.75,
#   'recent_checkin_id': 427234588,
#   'recent_created_at': 'Sat, 11 Mar 2017 18:25:36 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3.25,
#    'beer_abv': 12,
#    'beer_description': '',
#    'beer_ibu': 75,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-UprisingBelgianTrippelIPA_75235.jpeg',
#    'beer_name': 'Uprising Tripel IPA',
#    'beer_slug': 'iron-fist-brewing-co-uprising-tripel-ipa',
#    'beer_style': 'IPA - Belgian',
#    'bid': 75235,
#    'created_at': 'Sun, 28 Aug 2011 16:21:15 +0000',
#    'rating_count': 5075,
#    'rating_score': 3.708,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 2508,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-2508_cf598.jpeg',
#    'brewery_name': 'Iron Fist Brewing Co.',
#    'brewery_slug': 'iron-fist-brewing-co',
#    'contact': {'facebook': 'http://www.facebook.com/IronFistBrewing',
#     'instagram': '',
#     'twitter': 'IronFistBrewing',
#     'url': 'http://ironfistbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Vista',
#     'brewery_state': 'CA',
#     'lat': 33.1451,
#     'lng': -117.239}},
#   'count': 1,
#   'first_checkin_id': 427046524,
#   'first_created_at': 'Sat, 11 Mar 2017 15:10:38 -0800',
#   'first_had': 'Sat, 11 Mar 2017 15:10:38 -0800',
#   'rating_score': 3.25,
#   'recent_checkin_id': 427046524,
#   'recent_created_at': 'Sat, 11 Mar 2017 15:10:38 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3.25,
#    'beer_abv': 6.1,
#    'beer_description': 'Dry, toasty, and malty. Notes of caramel and biscuit',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#    'beer_name': 'Oktoberfist',
#    'beer_slug': 'iron-fist-brewing-co-oktoberfist',
#    'beer_style': 'Märzen',
#    'bid': 1778560,
#    'created_at': 'Sat, 15 Oct 2016 19:51:13 +0000',
#    'rating_count': 92,
#    'rating_score': 3.696,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 2508,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-2508_cf598.jpeg',
#    'brewery_name': 'Iron Fist Brewing Co.',
#    'brewery_slug': 'iron-fist-brewing-co',
#    'contact': {'facebook': 'http://www.facebook.com/IronFistBrewing',
#     'instagram': '',
#     'twitter': 'IronFistBrewing',
#     'url': 'http://ironfistbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Vista',
#     'brewery_state': 'CA',
#     'lat': 33.1451,
#     'lng': -117.239}},
#   'count': 1,
#   'first_checkin_id': 427045661,
#   'first_created_at': 'Sat, 11 Mar 2017 15:09:49 -0800',
#   'first_had': 'Sat, 11 Mar 2017 15:09:49 -0800',
#   'rating_score': 3.25,
#   'recent_checkin_id': 427045661,
#   'recent_created_at': 'Sat, 11 Mar 2017 15:09:49 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3.5,
#    'beer_abv': 8.1,
#    'beer_description': '',
#    'beer_ibu': 18,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-DubbelFisted_10905.jpeg',
#    'beer_name': 'Dubbel Fisted',
#    'beer_slug': 'iron-fist-brewing-co-dubbel-fisted',
#    'beer_style': 'Belgian Dubbel',
#    'bid': 10905,
#    'created_at': 'Thu, 25 Nov 2010 08:46:38 +0000',
#    'rating_count': 3956,
#    'rating_score': 3.59,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 2508,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-2508_cf598.jpeg',
#    'brewery_name': 'Iron Fist Brewing Co.',
#    'brewery_slug': 'iron-fist-brewing-co',
#    'contact': {'facebook': 'http://www.facebook.com/IronFistBrewing',
#     'instagram': '',
#     'twitter': 'IronFistBrewing',
#     'url': 'http://ironfistbrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Vista',
#     'brewery_state': 'CA',
#     'lat': 33.1451,
#     'lng': -117.239}},
#   'count': 1,
#   'first_checkin_id': 427040138,
#   'first_created_at': 'Sat, 11 Mar 2017 15:04:25 -0800',
#   'first_had': 'Sat, 11 Mar 2017 15:04:25 -0800',
#   'rating_score': 3.5,
#   'recent_checkin_id': 427040138,
#   'recent_created_at': 'Sat, 11 Mar 2017 15:04:25 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 2.5,
#    'beer_abv': 4.8,
#    'beer_description': '',
#    'beer_ibu': 30,
#    'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#    'beer_name': "Annabelle's Porter",
#    'beer_slug': 'arcana-brewing-annabelle-s-porter',
#    'beer_style': 'Porter - American',
#    'bid': 1385835,
#    'created_at': 'Sun, 10 Jan 2016 01:39:30 +0000',
#    'rating_count': 208,
#    'rating_score': 3.544,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 30892,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-fezziwigsbrewing_30892.jpeg',
#    'brewery_name': 'Arcana Brewing Company',
#    'brewery_slug': 'arcana-brewing-company',
#    'contact': {'facebook': 'http://www.facebook.com/ArcanaBrewing/',
#     'instagram': 'ArcanaBrewing',
#     'twitter': 'ArcanaBrewing',
#     'url': 'http://www.ArcanaBrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Carlsbad',
#     'brewery_state': 'CA',
#     'lat': 33.1416,
#     'lng': -117.275}},
#   'count': 1,
#   'first_checkin_id': 427037529,
#   'first_created_at': 'Sat, 11 Mar 2017 15:01:56 -0800',
#   'first_had': 'Sat, 11 Mar 2017 15:01:56 -0800',
#   'rating_score': 2.5,
#   'recent_checkin_id': 427037529,
#   'recent_created_at': 'Sat, 11 Mar 2017 15:01:56 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3,
#    'beer_abv': 6.5,
#    'beer_description': 'Incorporated locally California native White Sage and Sagebrush, coriander, and orange peels for a unique aroma and flavor.',
#    'beer_ibu': 34,
#    'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#    'beer_name': 'SD Saigeson',
#    'beer_slug': 'arcana-brewing-sd-saigeson',
#    'beer_style': 'Saison / Farmhouse Ale',
#    'bid': 727738,
#    'created_at': 'Fri, 27 Jun 2014 19:05:14 +0000',
#    'rating_count': 189,
#    'rating_score': 3.757,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 30892,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-fezziwigsbrewing_30892.jpeg',
#    'brewery_name': 'Arcana Brewing Company',
#    'brewery_slug': 'arcana-brewing-company',
#    'contact': {'facebook': 'http://www.facebook.com/ArcanaBrewing/',
#     'instagram': 'ArcanaBrewing',
#     'twitter': 'ArcanaBrewing',
#     'url': 'http://www.ArcanaBrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Carlsbad',
#     'brewery_state': 'CA',
#     'lat': 33.1416,
#     'lng': -117.275}},
#   'count': 1,
#   'first_checkin_id': 427036644,
#   'first_created_at': 'Sat, 11 Mar 2017 15:01:02 -0800',
#   'first_had': 'Sat, 11 Mar 2017 15:01:02 -0800',
#   'rating_score': 3,
#   'recent_checkin_id': 427036644,
#   'recent_created_at': 'Sat, 11 Mar 2017 15:01:02 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3.5,
#    'beer_abv': 5.6,
#    'beer_description': 'Sweet stout, a staple. Bitter chocolate, coffee, and vanilla notes.',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/assets/images/temp/badge-beer-default.png',
#    'beer_name': 'Infinity Stout',
#    'beer_slug': 'arcana-brewing-infinity-stout',
#    'beer_style': 'Stout - Other',
#    'bid': 376263,
#    'created_at': 'Fri, 31 May 2013 23:12:16 +0000',
#    'rating_count': 193,
#    'rating_score': 3.733,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 30892,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-fezziwigsbrewing_30892.jpeg',
#    'brewery_name': 'Arcana Brewing Company',
#    'brewery_slug': 'arcana-brewing-company',
#    'contact': {'facebook': 'http://www.facebook.com/ArcanaBrewing/',
#     'instagram': 'ArcanaBrewing',
#     'twitter': 'ArcanaBrewing',
#     'url': 'http://www.ArcanaBrewing.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Carlsbad',
#     'brewery_state': 'CA',
#     'lat': 33.1416,
#     'lng': -117.275}},
#   'count': 1,
#   'first_checkin_id': 427036014,
#   'first_created_at': 'Sat, 11 Mar 2017 15:00:23 -0800',
#   'first_had': 'Sat, 11 Mar 2017 15:00:23 -0800',
#   'rating_score': 3.5,
#   'recent_checkin_id': 427036014,
#   'recent_created_at': 'Sat, 11 Mar 2017 15:00:23 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 8.75,
#    'beer_description': 'A big, malty beast of a beer that exemplifies the way we roll here at Drake’s. Two-row malt is blended with Chocolate malt, roasted barley and dark Crystal malts to make up the grist. Only one hop addition, Columbus, is added for bittering, allowing the abundance of malt in this beer to shine through.  Drakonic is smooth and dense with flavors of licorice, coffee and chocolate and a slightly dry finish. Enjoy.',
#    'beer_ibu': 40,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-Drakonic_41626.jpeg',
#    'beer_name': 'Drakonic',
#    'beer_slug': 'drake-s-brewing-company-drakonic',
#    'beer_style': 'Stout - American Imperial / Double',
#    'bid': 41626,
#    'created_at': 'Sun, 03 Apr 2011 22:23:58 +0000',
#    'rating_count': 9913,
#    'rating_score': 3.902,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 464,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-464_df7ef.jpeg',
#    'brewery_name': "Drake's Brewing Company",
#    'brewery_slug': 'drake-s-brewing-company',
#    'contact': {'facebook': 'https://www.facebook.com/DrakesBeer/',
#     'instagram': 'drakesbrewing',
#     'twitter': 'DrakesBeer',
#     'url': 'http://drinkdrakes.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'San Leandro',
#     'brewery_state': 'CA',
#     'lat': 37.7176,
#     'lng': -122.182}},
#   'count': 1,
#   'first_checkin_id': 426805659,
#   'first_created_at': 'Sat, 11 Mar 2017 11:08:03 -0800',
#   'first_had': 'Sat, 11 Mar 2017 11:08:03 -0800',
#   'rating_score': 3.75,
#   'recent_checkin_id': 426805659,
#   'recent_created_at': 'Sat, 11 Mar 2017 11:08:03 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3.25,
#    'beer_abv': 5.7,
#    'beer_description': 'When it came to creating Ripper, we drew inspiration from the coastal surf cultures of SoCal and Oz. Sourcing classic Cascade from the Pacific Northwest and Australian Galaxy hops from…yes…Australia, we made a beer both lovers of frothy peaks and hoppy green buds will be stoked about. At the same time, we stayed true to our San Diego roots by pushing the hop boundaries of this style. While some might think it lingers on an edge far closer to an IPA, with all the dry-hop flavor and aroma, it’s actually right in line with the current-day interpretation of a West Coast pale. Ours just so happens to have an Aussie accent that’s cascading with a juicy amount of grapefruit and passion fruit hoppiness. So veg out or venture out. Either way, rip one open and taste this awesome golden nectar!',
#    'beer_ibu': 40,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-1652170_0a575_sm.jpeg',
#    'beer_name': 'Stone Ripper',
#    'beer_slug': 'stone-brewing-ripper',
#    'beer_style': 'Pale Ale - American',
#    'bid': 1652170,
#    'created_at': 'Tue, 19 Jul 2016 15:01:34 +0000',
#    'rating_count': 46927,
#    'rating_score': 3.757,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 1204,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-1204_23541.jpeg',
#    'brewery_name': 'Stone Brewing',
#    'brewery_slug': 'stone-brewing',
#    'contact': {'facebook': 'http://www.facebook.com/StoneBrewingCo',
#     'instagram': 'StoneBrewingCo',
#     'twitter': 'StoneBrewingCo',
#     'url': 'http://www.stonebrewing.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Escondido',
#     'brewery_state': 'CA',
#     'lat': 33.1157,
#     'lng': -117.12}},
#   'count': 1,
#   'first_checkin_id': 426424877,
#   'first_created_at': 'Fri, 10 Mar 2017 16:59:08 -0800',
#   'first_had': 'Fri, 10 Mar 2017 16:59:08 -0800',
#   'rating_score': 3.25,
#   'recent_checkin_id': 426424877,
#   'recent_created_at': 'Fri, 10 Mar 2017 16:59:08 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3,
#    'beer_abv': 5.8,
#    'beer_description': 'For far too long the tyrannical industrialized beer overlords have disgraced and cheapened the noble heritage of the pilsner with their relentless multi-generational downward drive to commercialized homogenization. Over decades, this once vaulted style has been slowly and methodically gutted, bringing forth a soulless and anemic result, all the while spending billions in advertising to convince the unwitting public that their fizzy yellow end result was beer. Well, I will not have it. We are striking back for true craft by stealing the pilsner back from their evil clutches, and restoring it to its almighty glory. They do it cheaply. We do it right. Choose vapidity, or choose righteousness...but whatever you do, choose wisely.',
#    'beer_ibu': 47,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-1529855_a7df4_sm.jpeg',
#    'beer_name': "Who You Callin' Wussie",
#    'beer_slug': 'arrogant-brewing-who-you-callin-wussie',
#    'beer_style': 'Pilsner - German',
#    'bid': 1529855,
#    'created_at': 'Thu, 28 Apr 2016 05:22:11 +0000',
#    'rating_count': 25365,
#    'rating_score': 3.695,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 234399,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-234399_0c2d9.jpeg',
#    'brewery_name': 'Arrogant Brewing',
#    'brewery_slug': 'arrogant-bastard-brewing',
#    'contact': {'facebook': 'https://www.facebook.com/arrogantbastardale',
#     'instagram': 'ArrogantBastard',
#     'twitter': 'ArrogantBastard',
#     'url': 'http://arrogantbastard.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Escondido',
#     'brewery_state': 'CA',
#     'lat': 33.116,
#     'lng': -117.12}},
#   'count': 1,
#   'first_checkin_id': 426420449,
#   'first_created_at': 'Fri, 10 Mar 2017 16:54:11 -0800',
#   'first_had': 'Fri, 10 Mar 2017 16:54:11 -0800',
#   'rating_score': 3,
#   'recent_checkin_id': 426420449,
#   'recent_created_at': 'Fri, 10 Mar 2017 16:54:11 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 4,
#    'beer_abv': 15,
#    'beer_description': 'Bold, yet smooth! Fermented with dates and figs, this bone-crusher has a completely unique flavor. At 15% abv, this beer is a great candidate for ageing. Over time, the beer dries out and the pit fruit flavors come forward and the hops recede.',
#    'beer_ibu': 85,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-dfhOldeSchool.jpg',
#    'beer_name': 'Olde School',
#    'beer_slug': 'dogfish-head-craft-brewery-olde-school',
#    'beer_style': 'Barleywine - American',
#    'bid': 818,
#    'created_at': 'Sat, 21 Aug 2010 09:26:35 +0000',
#    'rating_count': 26290,
#    'rating_score': 4.007,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 459,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-459_b3e4d.jpeg',
#    'brewery_name': 'Dogfish Head Craft Brewery',
#    'brewery_slug': 'dogfish-head-craft-brewery',
#    'contact': {'facebook': 'http://www.facebook.com/dogfishheadbeer',
#     'instagram': 'dogfishbeer',
#     'twitter': 'dogfishbeer',
#     'url': 'http://www.dogfish.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Milton',
#     'brewery_state': 'DE',
#     'lat': 38.7776,
#     'lng': -75.3099}},
#   'count': 1,
#   'first_checkin_id': 426420039,
#   'first_created_at': 'Fri, 10 Mar 2017 16:53:41 -0800',
#   'first_had': 'Fri, 10 Mar 2017 16:53:41 -0800',
#   'rating_score': 4,
#   'recent_checkin_id': 426420039,
#   'recent_created_at': 'Fri, 10 Mar 2017 16:53:41 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 4.25,
#    'beer_abv': 16.9,
#    'beer_description': 'Samaels is a super-caramelly, oak-aged English-style strong ale. Perhaps the least hoppy (sacrilege here at Avery!) beer we’ve brewed, to accentuate the malt. The oak is very apparent in this rich and high gravity ale, adding additional depth and complexity with a woody and cask-like nose and a pronounced vanilla flavor on the palate. With the addition of a more roasted malt in 2007, Samaels now delivers subtle bitterness to add balance to the natural sweetness. Cellarable for 10+ years.',
#    'beer_ibu': 41,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-9510_d19f4_sm.jpeg',
#    'beer_name': "Samael's Oak-Aged Ale",
#    'beer_slug': 'avery-brewing-co-samael-s-oak-aged-ale',
#    'beer_style': 'Strong Ale - English',
#    'bid': 9510,
#    'created_at': 'Tue, 16 Nov 2010 13:23:51 +0000',
#    'rating_count': 12767,
#    'rating_score': 3.967,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 62,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-avery.jpg',
#    'brewery_name': 'Avery Brewing Co.',
#    'brewery_slug': 'avery-brewing-co',
#    'contact': {'facebook': 'https://www.facebook.com/AveryBrewingCo',
#     'instagram': 'averybrewingco',
#     'twitter': 'AveryBrewingCo',
#     'url': 'http://www.averybrewing.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Boulder',
#     'brewery_state': 'CO',
#     'lat': 40.0625,
#     'lng': -105.205}},
#   'count': 1,
#   'first_checkin_id': 426331937,
#   'first_created_at': 'Fri, 10 Mar 2017 15:09:12 -0800',
#   'first_had': 'Fri, 10 Mar 2017 15:09:12 -0800',
#   'rating_score': 4.25,
#   'recent_checkin_id': 426331937,
#   'recent_created_at': 'Fri, 10 Mar 2017 15:09:12 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 7.2,
#    'beer_description': 'This is an aggressive ale. You probably won’t like it. It is quite doubtful that you have the taste or sophistication to be able to appreciate an ale of this quality and depth. We would suggest that you stick to safer and more familiar territory–maybe something with a multi-million dollar ad campaign aimed at convincing you it’s made in a little brewery, or one that implies that their tasteless fizzy yellow beverage will give you more sex appeal. Perhaps you think multi-million dollar ad campaigns make things taste better. Perhaps you’re mouthing your words as you read this.',
#    'beer_ibu': 100,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-18099_5ec15_sm.jpeg',
#    'beer_name': 'Arrogant Bastard Ale',
#    'beer_slug': 'arrogant-brewing-arrogant-bastard-ale',
#    'beer_style': 'Strong Ale - American',
#    'bid': 18099,
#    'created_at': 'Mon, 27 Dec 2010 22:34:38 +0000',
#    'rating_count': 196670,
#    'rating_score': 3.8,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 234399,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-234399_0c2d9.jpeg',
#    'brewery_name': 'Arrogant Brewing',
#    'brewery_slug': 'arrogant-bastard-brewing',
#    'contact': {'facebook': 'https://www.facebook.com/arrogantbastardale',
#     'instagram': 'ArrogantBastard',
#     'twitter': 'ArrogantBastard',
#     'url': 'http://arrogantbastard.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Escondido',
#     'brewery_state': 'CA',
#     'lat': 33.116,
#     'lng': -117.12}},
#   'count': 1,
#   'first_checkin_id': 426331497,
#   'first_created_at': 'Fri, 10 Mar 2017 15:08:38 -0800',
#   'first_had': 'Fri, 10 Mar 2017 15:08:38 -0800',
#   'rating_score': 3.75,
#   'recent_checkin_id': 426331497,
#   'recent_created_at': 'Fri, 10 Mar 2017 15:08:38 -0800',
#   'recent_created_at_timezone': '-8'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 6.5,
#    'beer_description': 'Confident that the brewing team would develop an outstanding single IPA, the name “Soul Style” refers to the grace of the rarely seen, soul style surfer who leans way back on the board, making each difficult maneuver appear effortless. Soul Style is the Green Flash approach the art of crafting the perfect IPA. Citra, Simcoe and Cascade hops are layered to allow bright tropical citrus to mingle with waves of floral notes that break gently on the palate.',
#    'beer_ibu': 75,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-795543_20de4_sm.jpeg',
#    'beer_name': 'Soul Style',
#    'beer_slug': 'green-flash-brewing-co-soul-style',
#    'beer_style': 'IPA - American',
#    'bid': 795543,
#    'created_at': 'Sat, 30 Aug 2014 03:32:54 +0000',
#    'rating_count': 101507,
#    'rating_score': 3.762,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 609,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-609_22ae7.jpeg',
#    'brewery_name': 'Green Flash Brewing Company',
#    'brewery_slug': 'green-flash-brewing-company',
#    'contact': {'facebook': 'https://www.facebook.com/GreenFlashBrew',
#     'instagram': 'GreenFlashBeer',
#     'twitter': 'GreenFlashBeer',
#     'url': 'http://www.greenflashbrew.com'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'San Diego',
#     'brewery_state': 'CA',
#     'lat': 32.9073,
#     'lng': -117.178}},
#   'count': 1,
#   'first_checkin_id': 425530791,
#   'first_created_at': 'Wed, 08 Mar 2017 07:15:57 -0800',
# ...
#    'beer_ibu': 75,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-833_2ab2a_sm.jpeg',
#    'beer_name': 'Yeti',
#    'beer_slug': 'great-divide-brewing-company-yeti',
#    'beer_style': 'Stout - American Imperial / Double',
#    'bid': 833,
#    'created_at': 'Sat, 21 Aug 2010 09:26:35 +0000',
#    'rating_count': 97027,
#    'rating_score': 3.956,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 604,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-604_621e5.jpeg',
#    'brewery_name': 'Great Divide Brewing Company',
#    'brewery_slug': 'great-divide-brewing-company',
#    'contact': {'facebook': 'http://www.facebook.com/greatdividebrew',
#     'instagram': 'greatdividebrew',
#     'twitter': 'greatdividebrew',
#     'url': 'http://greatdivide.com/'},
#    'country_name': 'United States',
#    'location': {'brewery_city': 'Denver',
#     'brewery_state': 'CO',
#     'lat': 39.7538,
#     'lng': -104.988}},
#   'count': 1,
#   'first_checkin_id': 417105942,
#   'first_created_at': 'Mon, 13 Feb 2017 13:45:19 -0700',
#   'first_had': 'Mon, 13 Feb 2017 13:45:19 -0700',
#   'rating_score': 4,
#   'recent_checkin_id': 417105942,
#   'recent_created_at': 'Mon, 13 Feb 2017 13:45:19 -0700',
#   'recent_created_at_timezone': '-7'},
#  {'beer': {'auth_rating': 3.25,
#    'beer_abv': 5,
#    'beer_description': 'Amarga y con un toque frutal, Raquel es perfecta para disfrutar después de un largo martes.',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-305007_aefeb_sm.jpeg',
#    'beer_name': 'Raquel Pale Ale',
#    'beer_slug': 'chelarte-s-a-s-raquel-pale-ale',
#    'beer_style': 'Pale Ale - American',
#    'bid': 305007,
#    'created_at': 'Sun, 03 Feb 2013 14:06:49 +0000',
#    'rating_count': 184,
#    'rating_score': 3.518,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 43992,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-43992_07f27.jpeg',
#    'brewery_name': 'Chelarte S.A.S.',
#    'brewery_slug': 'chelarte-s-a-s',
#    'contact': {'facebook': 'https://www.facebook.com/ChelarteCervezaArtesanal/',
#     'instagram': 'chelarte',
#     'twitter': 'ChelarteCerveza',
#     'url': 'http://www.chelarte.com/'},
#    'country_name': 'Colombia',
#    'location': {'brewery_city': 'Bogotá',
#     'brewery_state': 'Distrito Capital',
#     'lat': 4.74795,
#     'lng': -74.0352}},
#   'count': 1,
#   'first_checkin_id': 415097297,
#   'first_created_at': 'Wed, 08 Feb 2017 20:31:32 -0500',
#   'first_had': 'Wed, 08 Feb 2017 20:31:32 -0500',
#   'rating_score': 3.25,
#   'recent_checkin_id': 415097297,
#   'recent_created_at': 'Wed, 08 Feb 2017 20:31:32 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3,
#    'beer_abv': 4.7,
#    'beer_description': '',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-101691_293f5_sm.jpeg',
#    'beer_name': 'Club Colombia Negra',
#    'beer_slug': 'cerveceria-bavaria-club-colombia-negra',
#    'beer_style': 'Schwarzbier',
#    'bid': 101691,
#    'created_at': 'Wed, 23 Nov 2011 15:15:57 +0000',
#    'rating_count': 1768,
#    'rating_score': 3.246,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 86,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-CerveceriaBavariaSASABMiller_86.jpeg',
#    'brewery_name': 'Cervecería Bavaria',
#    'brewery_slug': 'cerveceria-bavaria',
#    'contact': {'facebook': 'https://www.facebook.com/amigosBAVARIA',
#     'instagram': '',
#     'twitter': 'BAVARIA_SA',
#     'url': 'http://www.bavaria.co/'},
#    'country_name': 'Colombia',
#    'location': {'brewery_city': 'Bogotá',
#     'brewery_state': 'Distrito Capital',
#     'lat': 4.71736,
#     'lng': -74.0987}},
#   'count': 1,
#   'first_checkin_id': 414716584,
#   'first_created_at': 'Mon, 06 Feb 2017 22:32:23 -0500',
#   'first_had': 'Mon, 06 Feb 2017 22:32:23 -0500',
#   'rating_score': 3,
#   'recent_checkin_id': 414716584,
#   'recent_created_at': 'Mon, 06 Feb 2017 22:32:23 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3.5,
#    'beer_abv': 6,
#    'beer_description': '',
#    'beer_ibu': 90,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-207724_0b632_sm.jpeg',
#    'beer_name': 'Septimazo Tipo IPA',
#    'beer_slug': 'bogota-beer-company-septimazo-tipo-ipa',
#    'beer_style': 'IPA - American',
#    'bid': 207724,
#    'created_at': 'Sun, 29 Jul 2012 20:16:24 +0000',
#    'rating_count': 955,
#    'rating_score': 3.683,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 4573,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-4573_b8c25.jpeg',
#    'brewery_name': 'Bogotá Beer Company',
#    'brewery_slug': 'bogota-beer-company',
#    'contact': {'facebook': 'https://www.facebook.com/BogotaBC',
#     'instagram': 'Bogotabeercompany',
#     'twitter': 'BogotaBeerCo',
#     'url': 'http://www.bogotabeercompany.com/'},
#    'country_name': 'Colombia',
#    'location': {'brewery_city': 'Bogotá',
#     'brewery_state': 'Distrito Capital',
#     'lat': 4.76489,
#     'lng': -74.033}},
#   'count': 1,
#   'first_checkin_id': 414378267,
#   'first_created_at': 'Sun, 05 Feb 2017 19:27:07 -0500',
#   'first_had': 'Sun, 05 Feb 2017 19:27:07 -0500',
#   'rating_score': 3.5,
#   'recent_checkin_id': 414378267,
#   'recent_created_at': 'Sun, 05 Feb 2017 19:27:07 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3,
#    'beer_abv': 5,
#    'beer_description': 'pale ale of British. Red, fruity and lupulosa.',
#    'beer_ibu': 39,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-17279_8d760_sm.jpeg',
#    'beer_name': 'Monserrate Roja',
#    'beer_slug': 'bogota-beer-company-monserrate-roja',
#    'beer_style': 'Red Ale - American Amber / Red',
#    'bid': 17279,
#    'created_at': 'Sat, 25 Dec 2010 18:46:52 +0000',
#    'rating_count': 1944,
#    'rating_score': 3.418,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 4573,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-4573_b8c25.jpeg',
#    'brewery_name': 'Bogotá Beer Company',
#    'brewery_slug': 'bogota-beer-company',
#    'contact': {'facebook': 'https://www.facebook.com/BogotaBC',
#     'instagram': 'Bogotabeercompany',
#     'twitter': 'BogotaBeerCo',
#     'url': 'http://www.bogotabeercompany.com/'},
#    'country_name': 'Colombia',
#    'location': {'brewery_city': 'Bogotá',
#     'brewery_state': 'Distrito Capital',
#     'lat': 4.76489,
#     'lng': -74.033}},
#   'count': 1,
#   'first_checkin_id': 414377400,
#   'first_created_at': 'Sun, 05 Feb 2017 19:26:31 -0500',
#   'first_had': 'Sun, 05 Feb 2017 19:26:31 -0500',
#   'rating_score': 3,
#   'recent_checkin_id': 414377400,
#   'recent_created_at': 'Sun, 05 Feb 2017 19:26:31 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 2.75,
#    'beer_abv': 4.7,
#    'beer_description': 'Pours a clear amber with some thin, creamy head. Looks like Yuengling. Nose has malt, stale malt, yeast, mild fruit, some faint nuttiness. Flavor follows, some regular bread, mildly grist, some mild apple, lemon. watery finish.',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-11106_ae1ec_sm.jpeg',
#    'beer_name': 'Club Colombia Roja',
#    'beer_slug': 'cerveceria-bavaria-club-colombia-roja',
#    'beer_style': 'Lager - Vienna',
#    'bid': 11106,
#    'created_at': 'Fri, 26 Nov 2010 08:20:03 +0000',
#    'rating_count': 2540,
#    'rating_score': 3.183,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 86,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-CerveceriaBavariaSASABMiller_86.jpeg',
#    'brewery_name': 'Cervecería Bavaria',
#    'brewery_slug': 'cerveceria-bavaria',
#    'contact': {'facebook': 'https://www.facebook.com/amigosBAVARIA',
#     'instagram': '',
#     'twitter': 'BAVARIA_SA',
#     'url': 'http://www.bavaria.co/'},
#    'country_name': 'Colombia',
#    'location': {'brewery_city': 'Bogotá',
#     'brewery_state': 'Distrito Capital',
#     'lat': 4.71736,
#     'lng': -74.0987}},
#   'count': 1,
#   'first_checkin_id': 413579683,
#   'first_created_at': 'Sat, 04 Feb 2017 16:25:42 -0500',
#   'first_had': 'Sat, 04 Feb 2017 16:25:42 -0500',
#   'rating_score': 2.75,
#   'recent_checkin_id': 413579683,
#   'recent_created_at': 'Sat, 04 Feb 2017 16:25:42 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 2.25,
#    'beer_abv': 4,
#    'beer_description': '',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-_19729_sm_f4162b6b4100ec6c77706dda81b911.jpeg',
#    'beer_name': 'Aguila',
#    'beer_slug': 'cerveceria-bavaria-s-a-sab-miller-aguila',
#    'beer_style': 'Lager - North American Adjunct',
#    'bid': 19729,
#    'created_at': 'Fri, 31 Dec 2010 18:45:43 +0000',
#    'rating_count': 12338,
#    'rating_score': 2.725,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 86,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-CerveceriaBavariaSASABMiller_86.jpeg',
#    'brewery_name': 'Cervecería Bavaria',
#    'brewery_slug': 'cerveceria-bavaria',
#    'contact': {'facebook': 'https://www.facebook.com/amigosBAVARIA',
#     'instagram': '',
#     'twitter': 'BAVARIA_SA',
#     'url': 'http://www.bavaria.co/'},
#    'country_name': 'Colombia',
#    'location': {'brewery_city': 'Bogotá',
#     'brewery_state': 'Distrito Capital',
#     'lat': 4.71736,
#     'lng': -74.0987}},
#   'count': 1,
#   'first_checkin_id': 413579022,
#   'first_created_at': 'Sat, 04 Feb 2017 16:25:06 -0500',
#   'first_had': 'Sat, 04 Feb 2017 16:25:06 -0500',
#   'rating_score': 2.25,
#   'recent_checkin_id': 413579022,
#   'recent_created_at': 'Sat, 04 Feb 2017 16:25:06 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 2.25,
#    'beer_abv': 4,
#    'beer_description': '',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-Poker_7101.jpeg',
#    'beer_name': 'Poker',
#    'beer_slug': 'cerveceria-bavaria-s-a-sab-miller-poker',
#    'beer_style': 'Lager - North American Adjunct',
#    'bid': 7101,
#    'created_at': 'Mon, 01 Nov 2010 23:37:38 +0000',
#    'rating_count': 1461,
#    'rating_score': 2.738,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 86,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-CerveceriaBavariaSASABMiller_86.jpeg',
#    'brewery_name': 'Cervecería Bavaria',
#    'brewery_slug': 'cerveceria-bavaria',
#    'contact': {'facebook': 'https://www.facebook.com/amigosBAVARIA',
#     'instagram': '',
#     'twitter': 'BAVARIA_SA',
#     'url': 'http://www.bavaria.co/'},
#    'country_name': 'Colombia',
#    'location': {'brewery_city': 'Bogotá',
#     'brewery_state': 'Distrito Capital',
#     'lat': 4.71736,
#     'lng': -74.0987}},
#   'count': 1,
#   'first_checkin_id': 412430652,
#   'first_created_at': 'Wed, 01 Feb 2017 21:08:49 -0500',
#   'first_had': 'Wed, 01 Feb 2017 21:08:49 -0500',
#   'rating_score': 2.25,
#   'recent_checkin_id': 412430652,
#   'recent_created_at': 'Wed, 01 Feb 2017 21:08:49 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3.5,
#    'beer_abv': 6.1,
#    'beer_description': 'Hoppy Wheat Ale with 50% wheat malt and lots of late hops additions and dryhops!\n',
#    'beer_ibu': 21,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-903495_83e9a_sm.jpeg',
#    'beer_name': 'La Nena Hoppy Wheat',
#    'beer_slug': 'cerveceria-barbarian-la-nena-hoppy-wheat',
#    'beer_style': 'Pale Wheat Ale - American',
#    'bid': 903495,
#    'created_at': 'Sun, 07 Dec 2014 22:52:34 +0000',
#    'rating_count': 1377,
#    'rating_score': 3.576,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 48665,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-48665_146c1.jpeg',
#    'brewery_name': 'Cervecería Barbarian ',
#    'brewery_slug': 'cerveceria-barbarian',
#    'contact': {'facebook': 'http://www.facebook.com/Cerveceria.Barbarian',
#     'instagram': 'CervezaBarbarian',
#     'twitter': 'BarbarianPeru',
#     'url': 'http://www.Barbarian.pe'},
#    'country_name': 'Peru',
#    'location': {'brewery_city': 'Lima',
#     'brewery_state': 'Lima',
#     'lat': -12.0125,
#     'lng': -76.913}},
#   'count': 1,
#   'first_checkin_id': 411836770,
#   'first_created_at': 'Sun, 29 Jan 2017 21:35:04 -0500',
#   'first_had': 'Sun, 29 Jan 2017 21:35:04 -0500',
#   'rating_score': 3.5,
#   'recent_checkin_id': 411836770,
#   'recent_created_at': 'Sun, 29 Jan 2017 21:35:04 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3.75,
#    'beer_abv': 8,
#    'beer_description': 'Mucha malta y cantidades absurdas de lúpulo se convierten en una cerveza poderosa con alto contenido alcohólico y agresivo amargor que redefine lo que conoces como cerveza.',
#    'beer_ibu': 80,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-365326_f4905_sm.jpeg',
#    'beer_name': '174 IPA',
#    'beer_slug': 'cerveceria-barbarian-174-ipa',
#    'beer_style': 'IPA - American',
#    'bid': 365326,
#    'created_at': 'Wed, 15 May 2013 20:49:28 +0000',
#    'rating_count': 1194,
#    'rating_score': 3.72,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 48665,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-48665_146c1.jpeg',
#    'brewery_name': 'Cervecería Barbarian ',
#    'brewery_slug': 'cerveceria-barbarian',
#    'contact': {'facebook': 'http://www.facebook.com/Cerveceria.Barbarian',
#     'instagram': 'CervezaBarbarian',
#     'twitter': 'BarbarianPeru',
#     'url': 'http://www.Barbarian.pe'},
#    'country_name': 'Peru',
#    'location': {'brewery_city': 'Lima',
#     'brewery_state': 'Lima',
#     'lat': -12.0125,
#     'lng': -76.913}},
#   'count': 1,
#   'first_checkin_id': 411139156,
#   'first_created_at': 'Sat, 28 Jan 2017 17:29:59 -0500',
#   'first_had': 'Sat, 28 Jan 2017 17:29:59 -0500',
#   'rating_score': 3.75,
#   'recent_checkin_id': 411139156,
#   'recent_created_at': 'Sat, 28 Jan 2017 17:29:59 -0500',
#   'recent_created_at_timezone': '-5'},
#  {'beer': {'auth_rating': 3.25,
#    'beer_abv': 5.3,
#    'beer_description': 'Our objective when elaborating this beer was to combine the pleasant fruity aromas originating from the traditional high fermentation (16-20°C) with the use of two types different of aromatic hops, that give to this beer unique and really unmistakable personality. Of golden color, intense and characteristic fruit aromas, with notes of caramel and fruits in finish, leaving a refreshing citrusy and dry bitterness. Ideal for accompanying red meats like lamb or like appetizer, where its delicate bitterness sensitizes the palate for the next flavors.',
#    'beer_ibu': 0,
#    'beer_label': 'https://untappd.akamaized.net/site/beer_logos/beer-22005_21ea8_sm.jpeg',
#    'beer_name': 'Golden Ale',
#    'beer_slug': 'cerveceria-kross-golden-ale',
#    'beer_style': 'Golden Ale',
#    'bid': 22005,
#    'created_at': 'Thu, 06 Jan 2011 13:12:18 +0000',
#    'rating_count': 1604,
#    'rating_score': 3.434,
#    'wish_list': False},
#   'brewery': {'brewery_active': 1,
#    'brewery_id': 6190,
#    'brewery_label': 'https://untappd.akamaized.net/site/brewery_logos/brewery-KrossMicrobrewBeers_6190.jpeg',
#    'brewery_name': 'Cervecería Kross',
#    'brewery_slug': 'cerveceria-kross',
#    'contact': {'facebook': 'http://www.facebook.com/cerveceriakross',
#     'instagram': 'CerveceriaKross',
#     'twitter': 'CerveceriaKross',
#     'url': 'http://www.kross.cl/'},
#    'country_name': 'Chile',
#    'location': {'brewery_city': 'Curacaví',
#     'brewery_state': 'Santiago',
#     'lat': -33.4039,
#     'lng': -71.1595}},
#   'count': 1,
#   'first_checkin_id': 410000110,
#   'first_created_at': 'Thu, 26 Jan 2017 04:27:19 -0300',
#   'first_had': 'Thu, 26 Jan 2017 04:27:19 -0300',
#   'rating_score': 3.25,
#   'recent_checkin_id': 410000110,
#   'recent_created_at': 'Thu, 26 Jan 2017 04:27:19 -0300',
#   'recent_created_at_timezone': '-3'}]

# %%
df = json_normalize(json_data['response']['beers']['items'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-232-5ba0c0259429> in <module>()
# ----> 1 df = json_normalize(json_data['response']['beers']['items'])
#
# /Users/joshuaemayer/anaconda/envs/python3/lib/python3.6/site-packages/pandas/io/json.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix)
#     791
#     792     if record_path is None:
# --> 793         if any([isinstance(x, dict) for x in compat.itervalues(data[0])]):
#     794             # naive normalization, this is idempotent for flat records
#     795             # and potentially will inflate the data considerably for
#
# IndexError: list index out of range

# %%
df.groupby('beer.beer_style').size().sort_values(ascending=False)
# Out:
# beer.beer_style
# IPA - American                        11
# Pale Ale - American                    9
# Stout - Russian Imperial               2
# Brown Ale - American                   2
# Stout - American Imperial / Double     2
# Lager - North American Adjunct         2
# Porter - American                      2
# Witbier                                1
# Belgian Dubbel                         1
# Golden Ale                             1
# IPA - Belgian                          1
# IPA - English                          1
# IPA - Imperial / Double                1
# Lager - Vienna                         1
# Märzen                                 1
# Pilsner - German                       1
# Pale Wheat Ale - American              1
# Strong Ale - English                   1
# Red Ale - American Amber / Red         1
# Rye Beer                               1
# Saison / Farmhouse Ale                 1
# Schwarzbier                            1
# Stout - American                       1
# Stout - Imperial / Double              1
# Stout - Other                          1
# Strong Ale - American                  1
# Barleywine - American                  1
# dtype: int64

# %%
df[['beer.beer_name', 'beer.rating_score', 'rating_score']].head()
# Out:
#        beer.beer_name  beer.rating_score  rating_score
# 0  Third Eye Pale Ale              3.606          3.75
# 1        Drumroll APA              3.812          4.00
# 2          Java Bound              3.801          3.50
# 3            One Claw              3.792          3.75
# 4          White Thai              3.572          3.50

# %%
json_data['meta']['code']
# Out:
# 200

# %%
json_data['response']['beers']['count']
# Out:
# 50

# %%
json_data['response']['total_count']
# Out:
# 202

# %%
#Initialize our zero vars
load_indicator = 0
api_call_counter = 0

#Since the Untappd API only allows 50 results per call, let's iterate until we acquire all of the results
#Hopefully we don't lose our API priveleges ;)
while load_indicator == 0 :
    # Package the request, send the request and catch the response: r
    r = requests.get(url+user_beer+username+client_id+client_secret+limit+str(limit_num)+offset+str(offset_num))
    # Let's keep track of how many API calls we are making, limit is 100 per hour
    api_count.append(format(datetime.datetime.now()))
    # Decode the JSON data into a dictionary: json_data
    json_data = r.json()
    if (json_data['meta']['code'] == 200) & (json_data['response']['beers']['count'] > 0) :
        df_name = json_normalize(json_data['response']['beers']['items'])
        print('Successfully Loaded & Normalized JSON Data')
        if api_call_counter == 0 :
            orig_df = df_name.copy()
            print('Succesfully Copied Original Dataframe')
        if api_call_counter > 0 :
            orig_df = orig_df.append(df_name, ignore_index=True)
            print('Successfully Appended to Original DataFrame ')
        api_call_counter += 1
        offset_num += limit_num
        print(api_call_counter, offset_num)
    else :
        load_indicator = 1
        print('Finished Loading JSON Files')
        print('API Calls Made: ' + str(len(api_count)))
# Out:
# Finished Loading JSON Files
# API Calls Made: 7

# %%
api_count
# Out:
# ['2017-04-14 20:43:09.160024',
#  '2017-04-14 20:43:12.232953',
#  '2017-04-14 20:43:15.816794',
#  '2017-04-14 20:43:18.307538',
#  '2017-04-14 20:43:19.769133',
#  '2017-04-14 20:43:21.052142']

# %%
#Yayyyyy!!!
orig_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 35 columns):
# beer.auth_rating                  205 non-null float64
# beer.beer_abv                     205 non-null float64
# beer.beer_description             205 non-null object
# beer.beer_ibu                     205 non-null int64
# beer.beer_label                   205 non-null object
# beer.beer_name                    205 non-null object
# beer.beer_slug                    205 non-null object
# beer.beer_style                   205 non-null object
# beer.bid                          205 non-null int64
# beer.created_at                   205 non-null object
# beer.rating_count                 205 non-null int64
# beer.rating_score                 205 non-null float64
# beer.wish_list                    205 non-null bool
# brewery.brewery_active            205 non-null int64
# brewery.brewery_id                205 non-null int64
# brewery.brewery_label             205 non-null object
# brewery.brewery_name              205 non-null object
# brewery.brewery_slug              205 non-null object
# brewery.contact.facebook          205 non-null object
# brewery.contact.instagram         205 non-null object
# brewery.contact.twitter           205 non-null object
# brewery.contact.url               205 non-null object
# brewery.country_name              205 non-null object
# brewery.location.brewery_city     205 non-null object
# brewery.location.brewery_state    205 non-null object
# brewery.location.lat              205 non-null float64
# brewery.location.lng              205 non-null float64
# count                             205 non-null int64
# first_checkin_id                  205 non-null int64
# first_created_at                  205 non-null object
# first_had                         205 non-null object
# rating_score                      205 non-null float64
# recent_checkin_id                 205 non-null int64
# recent_created_at                 205 non-null object
# recent_created_at_timezone        205 non-null object
# dtypes: bool(1), float64(6), int64(8), object(20)
# memory usage: 54.7+ KB

# %%
orig_df.groupby('beer.beer_style').size().sort_values(ascending=False).head(10)
# Out:
# beer.beer_style
# Lager - Pale                      30
# IPA - American                    23
# Pale Ale - American               17
# Lager - North American Adjunct     9
# Red Ale - American Amber / Red     9
# Märzen                             6
# Lager - Dunkel Munich              5
# Dunkelweizen                       5
# Pale Ale - New Zealand             4
# Saison / Farmhouse Ale             4
# dtype: int64

# %%
orig_df.groupby('beer.beer_style').size().sort_values(ascending=False).head(10).plot(kind='bar')

# %%
orig_df[['beer.beer_name', 'rating_score']].sort_values(by='rating_score', 
                                                        ascending=False).head(10).plot(x='beer.beer_name', kind='bar')

# %%
orig_df[['beer.beer_name', 'rating_score']].sort_values(by='rating_score', 
                                                        ascending=True).head(10).plot(x='beer.beer_name', kind='bar')

# %%
orig_df[orig_df['rating_score'] == 0.0].count()['beer.beer_name']
# Out:
# 36

# %%
orig_df['rating_score'].describe()
# Out:
# count    205.000000
# mean       2.776829
# std        1.417637
# min        0.000000
# 25%        2.500000
# 50%        3.250000
# 75%        3.750000
# max        5.000000
# Name: rating_score, dtype: float64

# %%
orig_df[orig_df['rating_score'] != 0.0]['rating_score'].describe()
# Out:
# count    169.000000
# mean       3.368343
# std        0.660349
# min        1.500000
# 25%        2.750000
# 50%        3.500000
# 75%        3.750000
# max        5.000000
# Name: rating_score, dtype: float64

# %%
#sns.barplot(x='beer.beer_name', y='rating_score', hue='beer.beer_style', data=orig_df)

# %%
sns.distplot(orig_df['rating_score'], axlabel='Beer Ratings')

# %%
my_ratings = orig_df[orig_df['rating_score'] != 0.0]['rating_score']
sns.distplot(my_ratings, axlabel='Beer Ratings')

# %%
sns.jointplot(x="beer.rating_score", y="rating_score", data=orig_df)

# %%
orig_df[orig_df['rating_score'] != 0.0]['beer.rating_score'].describe()
# Out:
# count    169.000000
# mean       3.399467
# std        0.479805
# min        0.000000
# 25%        3.104000
# 50%        3.512000
# 75%        3.717000
# max        4.568000
# Name: beer.rating_score, dtype: float64

# %%
orig_df[orig_df['rating_score'] != 0.0]['rating_score'].describe()
# Out:
# count    169.000000
# mean       3.368343
# std        0.660349
# min        1.500000
# 25%        2.750000
# 50%        3.500000
# 75%        3.750000
# max        5.000000
# Name: rating_score, dtype: float64

# %%
#orig_df.to_excel('beer-data.xlsx', sheet_name='Sheet1')
